# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
confit_str = """
# --- Global variables ---

[vars]
train = "/export/home/pwajsburt/data/eds-biomedic/train/"
val = "/export/home/pwajsburt/data/eds-biomedic/val/"
test = "/export/home/pwajsburt/data/eds-biomedic/test/"
gold_span_group = {"gold_spans": ["dosage", "form", "strength", "Chemical_and_drugs", "BIO", "BIO_comp"]}
default_attributes = {"Certainty": "Certain", "Temporality": "Present", "Family": False, "Negation": False, "Allergie": False}

# --- Pipeline ---

[nlp]
lang = "eds"
pipeline = [
           "normalizer",
           "sentencizer",
           "ner",
           "qualifier",
           ]
batch_size = 8
components = ${components}
tokenizer = {"@tokenizers": "eds.tokenizer"}

[components.normalizer]
@factory = "eds.normalizer"

[components.sentencizer]
@factory = "eds.sentences"

# NER component
[components.ner]
@factory = "eds.ner_crf"
mode = "joint"
window = 40
target_span_getter = ${vars.gold_span_group}
# Set spans as both to ents and in separate `ent.label` groups
span_setter = [ "ents", "*" ]
infer_span_setter = true

[components.ner.embedding]
@factory = "eds.text_cnn"
kernel_sizes = [3, 5, 7]

[components.ner.embedding.embedding]
@factory = "eds.transformer"
model = "/export/home/share/datascientists/models/finetuning-camembert-2021-07-29/"
#model = "/export/home/pwajsburt/data/models/embedding-whole-word/checkpoint-250000/"
window = 128
stride = 96

# Qualifier component
[components.qualifier]
@factory = "eds.span_qualifier"
keep_none = true

[components.qualifier.qualifiers]
Allergie = ["Chemical_and_drugs"]
Action = ["Chemical_and_drugs"]
Certainty = ["Chemical_and_drugs"]
Temporality = ["Chemical_and_drugs"]
Negation = ["Chemical_and_drugs"]
Family = ["Chemical_and_drugs"]

[components.qualifier.embedding]
@factory = "eds.span_pooler"
span_getter = {"Chemical_and_drugs": True, "gold_spans": "Chemical_and_drugs"}

[components.qualifier.embedding.embedding]
@factory = "eds.text_cnn"
kernel_sizes = [3, 5, 7]
#embedding = ${components.ner.embedding.embedding}

[components.qualifier.embedding.embedding.embedding]
@factory = "eds.transformer"
model = "/export/home/share/datascientists/models/finetuning-camembert-2021-07-29/"
#model = "/export/home/pwajsburt/data/models/embedding-whole-word/checkpoint-250000/"
window = 255
stride = 128
span_getter = {
    "@misc": "eds.span_sentence_getter",
    "span_getter": ${components.qualifier.embedding.span_getter},
    "min_context_words": 30
    }

# --- Scorers ---

[scorer.ner.exact_ner]
@scorers = "eds.ner_exact_scorer"
span_getter = ${vars.gold_span_group}

[scorer.qualifier.qualifier]
@scorers = "eds.span_classification_scorer"
span_getter = ${components.qualifier.embedding.span_getter}
qualifiers = ${components.qualifier.qualifiers}
default_values = ${vars.default_attributes}

# --- Data ---

[val_data]
[val_data.source]
@readers = "standoff"
path = ${vars.val}
span_setter = ${vars.gold_span_group}
default_attributes = ${vars.default_attributes}

[test_data]
[test_data.source]
@readers = "standoff"
path = ${vars.test}
span_setter = ${vars.gold_span_group}
default_attributes = ${vars.default_attributes}

[ner_train_dataloader]
batch_size = 2000 words
grad_accumulation_max_tokens = ${512 * 128}
pipe_names = ["ner"]
[ner_train_dataloader.data]
randomize = true
max_length = 128
multi_sentence = true
[ner_train_dataloader.data.source]
@readers = "standoff"
path = ${vars.train}
span_setter = ${vars.gold_span_group}
default_attributes = ${vars.default_attributes}

[qlf_train_dataloader]
batch_size = 64 spans
grad_accumulation_max_tokens = ${512 * 128}
pipe_names = ["qualifier"]
[qlf_train_dataloader.data]
randomize = true
max_length = 128
multi_sentence = true
filter_expr = "sum([e.label_ == 'Chemical_and_drugs' for e in doc.spans['gold_spans']]) > 0"
[qlf_train_dataloader.data.source]
@readers = "standoff"
path = ${vars.train}
span_setter = ${vars.gold_span_group}
default_attributes = ${vars.default_attributes}

# --- Scripts ---

[train]
nlp = ${nlp}
max_steps = 4000
validation_interval = ${train.max_steps//10}
warmup_rate = 0.1
transformer_lr = 5e-5
task_lr = 5e-5
scorer = ${scorer}
train_dataloader = [${ner_train_dataloader}, ${qlf_train_dataloader}]
val_data = ${val_data}
test_data = ${test_data}
loss_scales = {"ner": 1, "qualifier": 300}

[evaluate]
scorer = ${scorer}
model_path = "artifacts/model-last"
data = ${test_data}
"""

# %%
import yaml

# %%
import confit

# %%
from io import StringIO
dumper = ConfitDumper(StringIO())

# %%
dumper.flow_level
# Out:
# 0

# %%
import yaml

# Custom dumper subclass
class ConfitDumper(yaml.Dumper):
    pass

# Custom representer for lists to always dump inline
def custom_list_representer(dumper, data):
    return dumper.represent_sequence('tag:yaml.org,2002:seq', data, flow_style=True)

# Custom representer for dicts to dump inline only if no key starts with "@"
def custom_dict_representer(dumper, data):
    is_inline = dumper.flow_level > 0 and not any(key.startswith("@") or isinstance(value, dict) for key, value in data.items())
    at_key = next((k for k in data if k.startswith('@')), None)
    if at_key:
        tag = "!" + at_key[1:] + ': ' + data[at_key]
        data = dict(data)
        data.pop(at_key)
    else:
        tag = 'tag:yaml.org,2002:map'
    return dumper.represent_mapping(tag, data, flow_style=is_inline if len(data) else None)

# Add custom representers to our custom dumper
ConfitDumper.add_representer(list, custom_list_representer)
ConfitDumper.add_representer(dict, custom_dict_representer)
ConfitDumper.add_representer(confit.Config, custom_dict_representer)
ConfitDumper.add_representer(confit.config.Reference, lambda dumper, data: dumper.represent_scalar("tag:yaml.org,2002:str", str(data)))

# Example usage
data = {
    "list_example": [1, 2, 3],
    "dict_example_inline": {"key1": "value1", "key2": "value2"},
    "dict_example_block": {"@key1": "value1", "key2": "value2"}
}

# Dumping with the custom dumper
yaml_str = yaml.dump(confit.Config.from_str(confit_str), Dumper=ConfitDumper, sort_keys=False, width=float("inf"))
print(yaml_str)
# Out:
# vars:
#   train: /export/home/pwajsburt/data/eds-biomedic/train/
#   val: /export/home/pwajsburt/data/eds-biomedic/val/
#   test: /export/home/pwajsburt/data/eds-biomedic/test/
#   gold_span_group:
#     gold_spans: [dosage, form, strength, Chemical_and_drugs, BIO, BIO_comp]
#   default_attributes:
#     Certainty: Certain
#     Temporality: Present
#     Family: false
#     Negation: false
#     Allergie: false
# nlp:
#   lang: eds
#   pipeline: [normalizer, sentencizer, ner, qualifier]
#   batch_size: 8
#   components: ${components}
#   tokenizer: !tokenizers:%20eds.tokenizer {}
# components:
#   normalizer: !factory:%20eds.normalizer {}
#   sentencizer: !factory:%20eds.sentences {}
#   ner: !factory:%20eds.ner_crf
#     mode: joint
#     window: 40
#     target_span_getter: ${vars.gold_span_group}
#     span_setter: [ents, '*']
#     infer_span_setter: true
#     embedding: !factory:%20eds.text_cnn
#       kernel_sizes: [3, 5, 7]
#       embedding: !factory:%20eds.transformer
#         model: /export/home/share/datascientists/models/finetuning-camembert-2021-07-29/
#         window: 128
#         stride: 96
#   qualifier: !factory:%20eds.span_qualifier
#     keep_none: true
#     qualifiers:
#       Allergie: [Chemical_and_drugs]
#       Action: [Chemical_and_drugs]
#       Certainty: [Chemical_and_drugs]
#       Temporality: [Chemical_and_drugs]
#       Negation: [Chemical_and_drugs]
#       Family: [Chemical_and_drugs]
#     embedding: !factory:%20eds.span_pooler
#       span_getter:
#         Chemical_and_drugs: true
#         gold_spans: Chemical_and_drugs
#       embedding: !factory:%20eds.text_cnn
#         kernel_sizes: [3, 5, 7]
#         embedding: !factory:%20eds.transformer
#           model: /export/home/share/datascientists/models/finetuning-camembert-2021-07-29/
#           window: 255
#           stride: 128
#           span_getter: !misc:%20eds.span_sentence_getter
#             span_getter: ${components.qualifier.embedding.span_getter}
#             min_context_words: 30
# scorer:
#   ner:
#     exact_ner: !scorers:%20eds.ner_exact_scorer
#       span_getter: ${vars.gold_span_group}
#   qualifier:
#     qualifier: !scorers:%20eds.span_classification_scorer
#       span_getter: ${components.qualifier.embedding.span_getter}
#       qualifiers: ${components.qualifier.qualifiers}
#       default_values: ${vars.default_attributes}
# val_data:
#   source: !readers:%20standoff
#     path: ${vars.val}
#     span_setter: ${vars.gold_span_group}
#     default_attributes: ${vars.default_attributes}
# test_data:
#   source: !readers:%20standoff
#     path: ${vars.test}
#     span_setter: ${vars.gold_span_group}
#     default_attributes: ${vars.default_attributes}
# ner_train_dataloader:
#   batch_size: 2000 words
#   grad_accumulation_max_tokens: ${512 * 128}
#   pipe_names: [ner]
#   data:
#     randomize: true
#     max_length: 128
#     multi_sentence: true
#     source: !readers:%20standoff
#       path: ${vars.train}
#       span_setter: ${vars.gold_span_group}
#       default_attributes: ${vars.default_attributes}
# qlf_train_dataloader:
#   batch_size: 64 spans
#   grad_accumulation_max_tokens: ${512 * 128}
#   pipe_names: [qualifier]
#   data:
#     randomize: true
#     max_length: 128
#     multi_sentence: true
#     filter_expr: sum([e.label_ == 'Chemical_and_drugs' for e in doc.spans['gold_spans']]) > 0
#     source: !readers:%20standoff
#       path: ${vars.train}
#       span_setter: ${vars.gold_span_group}
#       default_attributes: ${vars.default_attributes}
# train:
#   nlp: ${nlp}
#   max_steps: 4000
#   validation_interval: ${train.max_steps//10}
#   warmup_rate: 0.1
#   transformer_lr: 5.0e-05
#   task_lr: 5.0e-05
#   scorer: ${scorer}
#   train_dataloader: ['${ner_train_dataloader}', '${qlf_train_dataloader}']
#   val_data: ${val_data}
#   test_data: ${test_data}
#   loss_scales:
#     ner: 1
#     qualifier: 300
# evaluate:
#   scorer: ${scorer}
#   model_path: artifacts/model-last
#   data: ${test_data}

# %%
import ruamel.yaml
ruamel.yaml.load

# %%
ruamel.yaml.load("""
train:
  nlp: ${nlp}
  max_steps: 4000
  validation_interval: ${train.max_steps//10}
  warmup_rate: 0.1
  transformer_lr: 5.0e-05
  task_lr: 5.0e-05
  scorer: ${scorer}
  train_dataloader:
      # !test
      - ${ner_train_dataloader}
      - ${qlf_train_dataloader}
  val_data: ${val_data}
  test_data: ${test_data}
  loss_scales:
    ner: 1
    qualifier: 300
""", ruamel.yaml.Loader)
# Out:
# ---------------------------------------------------------------------------
# ConstructorError                          Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 ruamel.yaml.load("""
#       2 train:
#       3   nlp: ${nlp}
#       4   max_steps: 4000
#       5   validation_interval: ${train.max_steps//10}
#       6   warmup_rate: 0.1
#       7   transformer_lr: 5.0e-05
#       8   task_lr: 5.0e-05
#       9   scorer: ${scorer}
#      10   train_dataloader:
#      11       !test
#      12       - ${ner_train_dataloader}
#      13       - ${qlf_train_dataloader}
#      14   val_data: ${val_data}
#      15   test_data: ${test_data}
#      16   loss_scales:
#      17     ner: 1
#      18     qualifier: 300
#      19 """, ruamel.yaml.Loader)
#
# File ~/Development/edspdf/.venv/lib/python3.8/site-packages/ruamel/yaml/main.py:1063, in load(stream, Loader, version, preserve_quotes)
#    1061 loader = Loader(stream, version, preserve_quotes=preserve_quotes)  # type: Any
#    1062 try:
# -> 1063     return loader._constructor.get_single_data()
#    1064 finally:
#    1065     loader._parser.dispose()
#
# File ~/Development/edspdf/.venv/lib/python3.8/site-packages/ruamel/yaml/constructor.py:113, in BaseConstructor.get_single_data(self)
#     111 node = self.composer.get_single_node()
#     112 if node is not None:
# --> 113     return self.construct_document(node)
#     114 return None
#
# File ~/Development/edspdf/.venv/lib/python3.8/site-packages/ruamel/yaml/constructor.py:122, in BaseConstructor.construct_document(self, node)
#     120     self.state_generators = []
#     121     for generator in state_generators:
# --> 122         for _dummy in generator:
#     123             pass
#     124 self.constructed_objects = {}
#
# File ~/Development/edspdf/.venv/lib/python3.8/site-packages/ruamel/yaml/constructor.py:612, in SafeConstructor.construct_yaml_map(self, node)
#     610 data: Dict[Any, Any] = self.yaml_base_dict_type()
#     611 yield data
# --> 612 value = self.construct_mapping(node)
#     613 data.update(value)
#
# File ~/Development/edspdf/.venv/lib/python3.8/site-packages/ruamel/yaml/constructor.py:410, in SafeConstructor.construct_mapping(self, node, deep)
#     408 if isinstance(node, MappingNode):
#     409     self.flatten_mapping(node)
# --> 410 return BaseConstructor.construct_mapping(self, node, deep=deep)
#
# File ~/Development/edspdf/.venv/lib/python3.8/site-packages/ruamel/yaml/constructor.py:241, in BaseConstructor.construct_mapping(self, node, deep)
#     233 if not isinstance(key, Hashable):
#     234     raise ConstructorError(
#     235         'while constructing a mapping',
#     236         node.start_mark,
#     237         'found unhashable key',
#     238         key_node.start_mark,
#     239     )
# --> 241 value = self.construct_object(value_node, deep=deep)
#     242 if check:
#     243     if self.check_mapping_key(node, key_node, mapping, key, value):
#
# File ~/Development/edspdf/.venv/lib/python3.8/site-packages/ruamel/yaml/constructor.py:144, in BaseConstructor.construct_object(self, node, deep)
#     140     # raise ConstructorError(
#     141     #     None, None, 'found unconstructable recursive node', node.start_mark
#     142     # )
#     143 self.recursive_objects[node] = None
# --> 144 data = self.construct_non_recursive_object(node)
#     146 self.constructed_objects[node] = data
#     147 del self.recursive_objects[node]
#
# File ~/Development/edspdf/.venv/lib/python3.8/site-packages/ruamel/yaml/constructor.py:178, in BaseConstructor.construct_non_recursive_object(self, node, tag)
#     176             constructor = self.__class__.construct_mapping
#     177 if tag_suffix is None:
# --> 178     data = constructor(self, node)
#     179 else:
#     180     data = constructor(self, tag_suffix, node)
#
# File ~/Development/edspdf/.venv/lib/python3.8/site-packages/ruamel/yaml/constructor.py:626, in SafeConstructor.construct_undefined(self, node)
#     625 def construct_undefined(self, node: Any) -> None:
# --> 626     raise ConstructorError(
#     627         None,
#     628         None,
#     629         f'could not determine a constructor for the tag {node.tag!r}',
#     630         node.start_mark,
#     631     )
#
# ConstructorError: could not determine a constructor for the tag '!test'
#   in "<unicode string>", line 11, column 7:
#           !test
#           ^ (line: 11)

# %%
from ruamel.yaml import YAML
from ruamel.yaml import YAMLError as _YAMLError

yaml = YAML(typ="rt")

# %%
#yaml.add_constructor('!test', lambda loader, item: loader.construct_mapping(item), yaml.Loader)
res = yaml.load("""
authors:
- !test
  author: Yukihiro Matsumoto
  title: Ruby in a Nutshell
  year: 2002
  isbn: 0-596-00214-9
# test
-
  _factory_: test:app
  author: Yukihiro Matsumoto
  title: Ruby in a Nutshell
  year: 2002
  isbn: 0-596-00214-9
""")
print(type(res))
res
# Out:
# <class 'ruamel.yaml.comments.CommentedMap'>
# {'authors': [{'author': 'Yukihiro Matsumoto', 'title': 'Ruby in a Nutshell', 'year': 2002, 'isbn': '0-596-00214-9'}, {'_target_': 'test:app', 'author': 'Yukihiro Matsumoto', 'title': 'Ruby in a Nutshell', 'year': 2002, 'isbn': '0-596-00214-9'}]}

# %%
res['authors'][0]
# Out:
# {'author': 'Yukihiro Matsumoto', 'title': 'Ruby in a Nutshell', 'year': 2002, 'isbn': '0-596-00214-9'}

# %%
_.tag
# Out:
# Tag('!test')

# %%
import os

# %%
for name in Path("/Users/perceval/Downloads/PDFs_annotés").glob("*.pdf"):
    content = Path(name).read_bytes()

# %%
# pip install edsnlp edspdf edspdf-mupdf python-docx
import edsnlp
import edspdf
import edspdf.utils.alignment
import rich.console
import os
from collections import defaultdict
from pathlib import Path
from fitz import Document
from docx.shared import RGBColor
import edsnlp
nlp = edsnlp.blank('eds')
nlp.add_pipe('eds.sentences')

pipeline = edspdf.Pipeline()
pipeline.add_pipe("mupdf-extractor")

for name in Path("/Users/perceval/Downloads/PDFs_annotés").glob("*.pdf"):
    content = Path(name).read_bytes()

    fitz_doc = Document(stream=content)
    doc = pipeline(content)

    colors = defaultdict(lambda: f"label-{len(colors)}")
    by_label = defaultdict(list)
    for page, fitz_page in zip(doc.pages, fitz_doc.pages()):
        #print("PAGE", page.page_num)
        boxes = []
        annots = list(fitz_page.get_drawings())
        #print("ANNOTS", len(annots), page.width, page.height)
        for annot in annots:
            for item in annot['items']:
                if item[0] == "c" and annot['color']:
                    color = colors[annot['color']]
                    w, h = page.width, page.height
                    x0, x1, y0, y1 = (
                        (item[1][0])/w,
                        (item[4][0])/w,
                        (item[1][1]-1)/h,
                        (item[4][1]+1)/h,
                    )
                    boxes.append(edspdf.Box(x0=x0, x1=x1, y0=y0, y1=y1, label=color, page_num=page.page_num))
        clusters = []
        #print("BOXES", len(boxes))
        for line in edspdf.utils.alignment.align_box_labels(boxes, page.text_boxes):
            if line.label is None:
                continue
            if (
                not len(clusters)
                or clusters[-1][-1].label != line.label
                or abs(clusters[-1][-1].y1 - line.y0) > (6 / page.height)
            ):
                clusters.append([line])
            else:
                clusters[-1].append(line)

        for cluster in clusters:
            by_label[cluster[0].label].append(cluster)

    out_filename = f"/Users/perceval/Downloads/PDFs_annotés/PDF_extraction/" + name.stem + ".docx"
    doc = docx.Document()
    doc.add_heading(name.stem, level=0)
    colors_by_label = {label: RGBColor(*(int(c * 255) for c in color)) for color, label in colors.items() if isinstance(color, tuple)}
    #console = rich.console.Console(file=f)
    for label, clusters in by_label.items():
        title = clusters[0][0].text
        clusters = [clusters[0][1:], *clusters[1:]]
        heading = doc.add_heading(level=1)
        run = heading.add_run(title)
        run.font.color.rgb = colors_by_label[label]
        print("--------- " + title + " ----------")
        for cluster in clusters:
            paragraph = "\n".join(line.text for line in cluster) + "\n"
            paragraph = "\n".join(sent.text.replace("\n", " ") for sent in nlp(paragraph).sents)
            doc.add_paragraph(paragraph)
            doc.add_paragraph()
            print(paragraph)
    doc.save(out_filename)
# Out:
# --------- NLP ----------
#
# --------- Réglementation ----------
#
# --------- Communication ----------
#
# à la défi quelqu'un qui connaît bien pilote puis je veux dire comment je fais comment elle s'appelle elle était à la dst avant verra verra je vais appeler verra je vais lui mettre un sms sur son 06 salut verra c'est christophe j'ai telle question qu'est ce que je peux faire c'est pas c'est pas formellement probablement le bon circuit et après on fait marcher le réseau
# --------- Fonctionnalités ----------
#
# J'avoue que s'il y avait des requêteurs plus faciles à utiliser, plus simples, probablement que je regarderais ces flux aussi sur d'autres sites,
# On ne peut malheureusement pas, en termes d'activité des urgences, tout construire dans des rapports préétablis, et on a besoin d'une grande réactivité pour aller voir les passages par rapport à un code diagnostique dans un RPU, les passages par rapport à une tranche d'âge, par rapport à un certain nombre d'horaires, d'horaires complexes, pour voir si on identifie un signal faible à faire remonter un début de crise ou des choses comme ça.
# Donc c'est une activité qui est assez, je dirais, assez particulière, parce qu'on est proche du temps réel, on est sur au maximum le J-1, parce que voilà, si on attend les données du mois dernier, on n'est plus dans la crise.
# ce qui est dommage c'est qu'on a un bout de truc sur Condor, on a un bout de truc sur le DS, on a les RPU qu'on n'est pas capable de capter entre guillemets qui partent au GCS Cézanne en automatique toutes les nuits à 1h du matin pour remonter à Santé Publique France et on n'est pas capable en interne de pouvoir travailler dessus quoi c'est quelque part c'est aberrant si on veut récupérer nos RPU il faut qu'on demande au Cézanne qui nous renvoie le fichier quoi c'est juste le monde à l'envers
# sur les tensions hivernales voilà c'est ça un rapport comme ça qui tombe qui tombe le soir en fin de journée moi ça me sert plus rien j'avais besoin j'en ai besoin plutôt le matin en fait il ya plein de choses qui sont faites par par la dsn par tout le monde mais il ya des petits calages à organiser puis il ya un travail de fond sur voilà comment encore plus optimisé de donner ce que sur les urgences c'est quand même un malade qui s'inscrit toutes les 15 secondes à l'assistance publique donc ça fait des flux de données importantes des milles de données là dessus ils sont probablement sous exploité demander l'avis à yuri j'en dira tout autant on est une petite bande on se connaît tous un donc un peu plus un peu plus voilà et ce qui est dommage c'est qu'institutionnellement ne puisse pas plus capitaliser dessus quoi
# Voilà, donc ce ne serait pas honnête de ma part de dire c'est très bien, c'est pas bien, il faudrait que ce soit plus ergonomique.
# Voilà, ça tourne, ça répond aux petites questions que je pose quand j'en ai besoin.
# Le minimum, j'aimerais éventuellement pouvoir le maîtriser un peu plus.
# Mais voilà.
# Véra m'a dit que c'était quand même un outil compliqué.
# Et comme je n'ai pas forcément un temps immense à me consacrer à beaucoup de choses, j'essaye d'aller au plus pratique.
# --------- Type/dispo/structure des données ----------
#
# par rapport à ce qu'on aimerait bien qu'il se déverse dans l'EDS, mais qui ne se déverse pas, c'est les données des urgences.
# Ça, je ne suis pas le seul à enfoncer le clou sur ce sujet, et ce, d'autant que je vais avoir en charge une partie du suivi et du pilotage de l'activité pendant les JO.
# En fait, quand on commence à s'intéresser à de la donnée, ça donne faim.
# Et je dirais que là, on a le hors-d'œuvre.
# Mais derrière, de temps en temps, on aimerait pouvoir poser un certain nombre de choses et toute la difficulté.
# On a les rapports qui tournent en base sur les urgences, le suivi de l'activité, le URGE 10, le URGE 20, qui sont très bien faits.
# Et derrière, en tout cas, j'aimerais pouvoir parfois mettre une variable de plus, regarder sur une tranche horaire en plus.
# Parce que là, on a un regard assez grand.
# Et de temps en temps, pour pouvoir analyser un flux de passages aux urgences, il faut aller voir un petit peu plus dans le dur.
# Et ces données-là, pour l'instant, on ne les a pas dans l'EDS.
# Soit on demande aux collègues des urgences s'ils peuvent regarder eux-mêmes dans Orbis, dans leur rapport, parce qu'il y a des choses qui sortent d'Orbis.
# Et parfois, ça génère un peu de...
# de complexité, ce d'autant que les demandes, les sollicitations, quand on nous demande ça pour la direction générale, ça ne s'inscrit pas dans un plan de travail de recherche sur six mois.
# Mais il faut la réponse pour le soir même ou pour le lendemain.
# c'est du temps réel c'est-à-dire
# c'est des données disponibles le matin des données de la veille disponibles le matin voilà c'est ça c'est les données de 0h à 0h et on les a à 9h ou 9h30 le matin
# ce que j'ai du mal à comprendre c'est qu'on a des données qui partent de chez nous qui sont sur des fichiers extraits à chez Puget je ne sais plus 2 ou 3 heures du matin qui montent au GCS Cézanne et après à Santé publique France à midi le GCS envoie une analyse qui vaut ce qu'elle vaut avec le SAMétéo des urgences et je me dis si le flux il part de chez nous il y a bien un moment où on peut mettre un capteur pour récupérer le flux en interne et travailler dessus donc il y a peut-être une construction du système dans sa globalité il y a peut-être quelque chose à repenser mais c'est aberrant
# --------- Général ----------
#
# --------- Méthodologie ----------
#
# --------- Contournement ----------
#
# --------- Pilotage ----------
#
# Et donc on avait construit un rapport, sur des patients qui se présentent aux urgences de Louis-Maurier et d'Ambroise-Pareil, en les triant par les communes de provenance et les moyens d'arrivée, pour pouvoir voir les reports de charges quand l'hôpital de Neuilly ou l'hôpital Foch à Surenne ferment leurs portes des urgences la nuit,
# voir comment se redistribue la charge de ces communes-là, sur nos hôpitaux.
# Ça a un impact majeur en termes d'organisation pour les équipes, ça a un impact majeur en termes de pilotage, et donc c'est autour de tous ces flux-là, à titre personnel, que j'ai un intérêt à utiliser ce type d'outil.
# --------- Argent ----------
#
# --------- NLP ----------
#
# --------- Réglementation ----------
#
# --------- Communication ----------
#
# Je n'ai pas encore compris à qui demander la maintenance des requêtes télémédecine.
# Moi, je continue de demander à la DST, mais ça ne produit pas grand-chose,
# --------- Fonctionnalités ----------
#
# --------- Type/dispo/structure des données ----------
#
# Je n'ai pas l'activité par box, quoi.
# Parce qu'à aucun moment, on écrit quelque part, mais ça, je l'ai déjà fait remonter plein de fois.
# À aucun moment.
# On a l'activité par box, on a l'activité par spécialité, et la correspondance spécialité box, elle est faite…
# Il n'y a pas d'outil informatisé, donc elle est faite dans Excel, et du coup, c'est extrêmement compliqué de calculer un taux d'occupation d'un box, alors qu'on l'a pour le bloc opératoire, taux d'occupation d'une salle, on l'a.
# et du coup, la seule façon que j'ai eu de m'en sortir, c'était, ben, j'ai rajouté trois box de plus dans le nouveau plateau, en disant, ben, voilà, ça… C'est toujours trois box de plus.
# --------- Général ----------
#
# Donc, voilà, en fait, finalement, les données, j'en ai besoin régulièrement, mais je ne sais pas comment les avoir autrement qu'en demandant à ceux qui, voilà, savent un peu mieux faire.
# Moi, dans mon métier de DOP, je n'ai pas d'action très réactive aujourd'hui même, en fait, de temps réel.
# Enfin, moi, les trois que je suis, c'est au standard de l'hôpital, dans les centres de prise de rendez-vous téléphonique et auprès des secrétaires médicales, voilà, pour savoir si l'hôpital répond au téléphone.
# Mais ça, c'est parce que c'est une de mes champs de responsabilité.
# Donc, c'est la messagerie sécurisée, mais pour les patients, pour communiquer aux patients les documents de santé plutôt que, comme on le fait aujourd'hui, par mail, sur Gmail, quoi.
# Donc, je voudrais qu'on utilise la messagerie sécurisée citoyenne
# qui est en plus l'avantage de se retrouver dans mon espace santé.
# Et permettre aux patients d'enregistrer dans mon DMP sa convoque ou sa prescription ou son compte rendu.
# Et pour moi, c'est un enjeu parce qu'en pédiatrie, mon APHP.
# fr ne permet pas aux parents de récupérer les documents de leur enfant puisque mon APHP.
# fr ne gère pas les ayants droit.
# Alors que l'espace national, le DMP, lui, les parents peuvent accéder au DMP de leur enfant pour qu'ils puissent pour peu que leur enfant soit sur leur carte vitale.
# Donc, je voudrais développer la messagerie sécurisée citoyenne.
# --------- Méthodologie ----------
#
# --------- Contournement ----------
#
# --------- Pilotage ----------
#
# pense que la meilleure façon de discuter librement ok aujourd'hui j'ai un usage fortuit de pilote pour l'activité de télémédecine je ne sais pas comment j'ai entendu parler de ça mais un peu par hasard quelqu'un m'a parlé de pilote et du coup j'ai demandé mes accès j'ai eu l'accès à l'outil ça fait un an et demi maintenant j'ai eu l'accès à l'outil j'ai pas alors j'ai pas fait ce qu'il faut non plus pour me former ou je sais pas quoi donc je suis allé bidouiller dedans j'ai trouvé des requêtes je me suis mis à enregistrer mes requêtes voilà dont j'ai besoin et donc j'ai mes requêtes aujourd'hui sur les activités enfin ce qui est lié à la télémédecine téléconsulte et l'expertise télésurveillance qui me sont absolument essentielles parce que ça me permet à the notamment sur la téléconsultation comparer comparer qu'est ce qui est facturé par rapport à ce qui est réalisé dans orbis rendez vous et évaluer voilà la sous facturation les actes qui sont codés par d'autres être code et du coup comprendre un peu mieux quel type de téléconsulte sont faits dans les services donc pour moi ça c'est essentiel donc ça c'est à peu près le seul
# je parle au nom des dopes du ghu alors qu'en fait on a on a très souvent très souvent on fait le constat que là on aurait besoin d'avoir telle info sur les volumes de consultes sur le plateau sur l'activité aux urgences sur l'activité de l'âge des gilles sur tout un tas de choses et et dans ces situations systématiquement on enfin moi je demande aux dîmes les données et il met ça il est charmant et etc mais la différence entre demander aux dîmes et accéder moi-même à la requête c'est que quand j'accède moi-même à la requête j'y vais de façon régulière je vois comment ça évolue je peux réagir au fur et à mesure le dim je fais une enquête ponctuelle une fois ça me donne un état des lieux la dernière fois la dernière que dernière fois que je les sollicitais c'était
# et une DMS plus petite qu'à Cochin, et donc en fait ça montre que le service déborde, donc il déborde sur l'hôtel et ça se traduit par des baisses de DMS, donc c'est bien des séjours qu'on raccourcit pour aller à l'hôtel, mais ça je ne l'ai pas en continu, je ne vois pas la cinétique, j'ai fait l'analyse une fois, ça m'a permis de tester une hypothèse que j'avais, d'avoir une confirmation à un moment donné, puis après je referme, je ne sais pas quand est-ce que je retournerai vers cette analyse, alors que ça serait quelque chose qui serait pertinent de surveiller au fil de l'eau pour voir et réagir quand je vois que ça commence à décrocher.
# C'est un besoin d'autonomie en fait.
# Donc voilà, ma crainte c'était, on envoie les patients à l'hôtel alors qu'il y a encore...
# Il y a encore des lits vides à l'hôpital et donc on utilise l'hôtel parce que ça nous plaît ou c'est plus simple ou ça cache un défaut d'organisation.
# Et là, en réalité, quand on a un taux d'occupation de plus de 100%, ça veut dire qu'il y a tout le temps tous les lits pleins.
# Donc les patients qui vont à l'hôtel, c'est bien un lit qui est libéré pour quelqu'un d'autre et pas un lit qui est libéré pour être laissé vide, par exemple.
# Et la durée moyenne de séjour, le fait qu'elle se raccourcisse, montre que...
# Au lieu de garder trois nuits et une patiente, on ne la garde que deux à chaque fois qu'on envoie une fois à l'hôtel, puisque du coup, la durée moyenne baisse, il y a plus de séjour de deux, voilà, à peu près.
# Mais il y a sans doute ça quelque part dans Pilote, mais je ne sais pas l'utiliser.
# À part sur la télémédecine où j'ai toujours les mêmes requêtes, le reste du temps, ça va être assez dépendant de la question qui se pose.
# Donc, je passe par la cadre, je lui demande de me le prouver.
# Elle m'apporte des éléments de preuve.
# Après, je vais voir le DIM, je lui demande ce qu'il pense de ces éléments de preuve.
# Bon, il se trouve que tout le monde a l'air d'accord, donc je me dis que ça doit être vrai.
# Mais j'ai assez peu d'éléments.
# C'est-à-dire, est-ce qu'il y a un certain nombre d'actes d'HDJ avec tant de places, ou des ratios, tout ça, ça te semble correct ou pas ?
# Toi, t'as combien chez toi ?
# Et on se compare, on fait beaucoup de comparaisons entre d'hôpes.
# Mais c'est peut-être juste un défaut de formation, si ça se trouve, parce qu'en tant que pilote, il y a tout ça.
# Mais si je savais où aller les chercher, je pense que j'irais bien plus fréquemment m'appuyer sur des données, et pour le coup, pour avoir à travailler à la nappe, je sais l'importance que ça a de partir de données objectives qui permettent de poser le sujet, quoi.
# Mais là, je fais beaucoup de choses de façon complètement subjective, et ce n'est pas satisfaisant.
# Et quand j'ai commencé à tripatouiller dans Pilote, à aller voir les choses, ce que je trouve très...
# Enfin, pas très agréable, c'est qu'il y a plein de requêtes dont je ne sais pas si elles sont fiables, et je ne sais pas qui en est l'auteur, le propriétaire...
# Enfin, voilà, j'utilise des requêtes de gens.
# Parce que j'utilise le moteur de recherche pour chercher un mot-clé et voir ce que ça me donne.
# Voilà, consultation, je vais avoir tout un tas de requêtes, et vu le titre, je vais chercher l'une ou l'autre des requêtes.
# Moi, c'est surtout la fiabilité de ce que tu peux trouver par toi-même dans Pilote qui est un peu dommage, quoi.
# Depuis l'été dernier, mon rapport de télésurveillance, il me dit qu'il n'y a plus aucune activité dans le GFU parce qu'on a changé les lettres clés, ils ne les ont pas changées dans la requête, quoi.
# Mais je ne sais pas qui est propriétaire de cette requête pour lui demander de la mettre à jour pour intégrer les nouvelles lettres clés.
# Les urgences, vraiment, j'en ai besoin tous les jours.
# Enfin, pour le coup, moi, l'indicateur de passage aux urgences, pour moi, il est extrêmement important.
# Enfin, ce que je trouve très intéressant dans Pilote, c'est le partage des requêtes.
# Ce qui m'a clairement manqué, c'est de...
# Je trouve qu'il manque de doc.
# C'est-à-dire que, quand on exécute une requête, on n'a pas la présentation de la requête qui dit, par exemple, l'objectif de la requête, les précautions ou les limites, ou, attention, ça ne concerne que...
# ça ne prend en compte que tel type d'activité, ou, attention, ça exclut d'emblée tel type de séjour pour telle raison.
# c'est-à-dire que je prends une requête, je l'exécute, mais en fait, je ne suis pas tout à fait sûr que le résultat...
# Enfin, le résultat, il est sans doute juste, mais est-ce que c'est ce que je veux, je n'en sais trop rien.
# Peut-être qu'avec un petit webinaire d'une heure, ça m'aurait fait gagner du temps.
# Et curieusement, les autres jobs du GHU, en fait, n'utilisent pas Pilote et quand ils ont besoin de stats, me demandent de regarder dans Pilote, quoi.
# Alors que je ne suis quand même pas très, très doué sur cet outil.
# Voilà, ça mériterait d'être plus approprié, je pense.
# Au niveau de la granularité des paramètres, en fait, qui n'est pas suffisamment profond.
# Alors, si ça se trouve, l'outil le permet, mais les requêtes que j'ai vues laissent assez peu de marge sur le paramétrage.
# Ok, moi, ce qui me semblera intéressant, c'est de penser, mais on peut réfléchir aussi entre DOP, il y en a peut-être qui sont beaucoup plus familiers de Pilote que moi, mais à un package dans Pilote, un package de requêtes qui sont pertinentes pour l'activité d'un DOP.
# Enfin voilà, plutôt le service directement utile pour le DOP, ça c'est la première chose.
# Et une deuxième chose, c'est,
# comment le DOP peut promouvoir des usages de l'EDS dans les services ?
# Parce que pour le coup, on est en lien avec les médecins au quotidien.
# Et moi, je ne suis pas foutu de leur dire, mais est-ce que vous avez pensé à solliciter telle requête ?
# Caroline, on parlait justement du rôle que je trouve, moi, du DOP, de pousser de l'innovation dans les services, en imaginant, enfin, voilà, en testant des choses, etc.
# Moi, si j'arrive avec ça de plus dans ma besace, en voyant un médecin, je pourrais lui dire, je pourrais lui proposer ça comme une des pistes potentielles pour voir comment améliorer son activité, quoi.
# Et en particulier, quand je travaille avec des services sur des évolutions d'activité, extension, conversion en HDJ, etc.,
# le fait de savoir que je peux aller chercher, voilà, des trucs dans l'EDS,
# ça peut m'être précieux, voilà.
# Donc, enfin, je veux dire, il faut l'imaginer à deux niveaux, quoi.
# Le service rendu direct, mon tableau de bord dans mon bureau qui m'aide à piloter au quotidien, mais aussi comment est-ce que je peux promouvoir les services de l'EDS dans les services pour qu'ils soient eux-mêmes demandeurs de choses qui aident tout le monde à avancer, quoi.
# Et sur la partie, donc ça, c'est effectivement plutôt nous pouvoir toutier, vous outiller au niveau des dots sur quelle est l'offre de service, qu'est-ce qui est possible de faire, comment, à travers quels outils, et pouvoir vous donner matière à faire la promotion ou accompagner, effectivement, les services.
# --------- Argent ----------
#
# --------- NLP ----------
#
# Il y a des données qui sont bizarrement, de mon point de vue, collectées sous une forme non structurée, sous la forme de comptes rendus en PDF, alors que les données à la base existent de manière structurée.
# C'est...
# Je sais.
# Il y a des données...
# Alors, je ne les ai pas vues, mais souvent, je ne suis pas allé vérifier moi-même, donc ce que je vais dire est impossible, mais il y a des données qui sont recueillies, enfin qui existent.
# Une pression artérielle, donc elle est...
# Imaginons, ce n'est pas forcément un bon exemple, mais une pression artérielle va éventuellement...
# Ce n'est pas un bon exemple, mais peu importe, va éventuellement être enregistrée sous la forme d'un PDF.
# D'accord.
# Et ça, ça limite le...
# Ça rend compliqué l'exploitation ultérieure de la donnée, si elle est dans un PDF, il va falloir que je traite le PDF pour le sortir du PDF, alors que si elle était dans une cellule, dans un tableau...
# Un PDF, ça sert à donner à quelqu'un et à lire.
# Ça marche très bien pour ça.
# Mais moi, si je veux analyser la donnée, mes PDF, ça va me prendre 10 jours de plus de travail.
# S'ils sont dans ma colonne, je vais...
# Ok.
# C'est immédiat.
# --------- Réglementation ----------
#
# Alors, on n'est pas dans l'objectif de votre venue, mais la recherche technique, elle est régulée, organisée, procédurée sous tous ses aspects.
# Sauf l'analyse des données.
# L'analyse des données.
# Chacun fait comme il veut.
# Chacun fait comme il veut.
# Je ne parle pas de DS, je parle de la recherche technique organisée par les URQ.
# Il y a 12 URQ, 13 ou 14, en comptant le CFEP, peut-être l'URQ-ECO, et il y a 12, 13 ou 14 façons de faire.
# Et pourquoi c'est très important ?
# Un jour, la NSM, la NSM ou la CNIL va venir et demander à la DSM et ou à la DSM.
# Et pourquoi c'est très important ?
# On fait en sorte que les données soient toujours traitées dans les murs.
# Mais ce qui veut dire, vous êtes en télétravail, vous devez traiter des données, comment vous faites pour les traiter dans les murs ?
# Si je vous dis, je ne veux pas que ce soit sur un portable, donc ce que je dis à mes statisticiens, je ne veux pas que ce soit sur les portables.
# Si c'est sur le portable, du coup, ce n'est pas protégé par les murs.
# Je dis que c'est important qu'il y ait cette couche de protection.
# Mais aujourd'hui, on ne sait pas, la PHP ne sait pas organiser.
# Il y a de nombreux entrepôts, on ne sait pas rentrer dans les clous du référentiel de la CNIL.
# Et il y en a qui se présentent de manière réglementaire très mal, mais qui pourtant sont extrêmement importants.
# C'est par exemple les données qui sont collectées dans le cadre de RCP.
# RCP, c'est les réunions collégiales en cancérologie, dans lesquelles les dossiers des patients sont présentés.
# Leurs diagnostics, leurs pronostics, et les traitements sont collégialement décidés.
# A cette occasion-là, sont collectées des données sur lesquelles ensuite sont fabriquées des recherches et des publications.
# Aujourd'hui, moi j'en ai connaissance de 4-5 qui existent depuis 15-20 ans à la PHP, en dehors de cadre légal.
# Donc ils ont accumulé leurs trucs.
# Il n'y a pas de plus de conventions entre les établissements.
# Mais à l'heure actuelle, pour remettre ça dans les clous, il faudrait qu'on soit capable d'organiser une structure entrepôt qui respecte le référentiel.
# Parce qu'on ne peut pas aller à la CNIL en disant qu'on voudrait régulariser ça si on n'est pas capable de leur proposer une régularisation qui, à partir de maintenant, au moins, va respecter les choses.
# Et ça, c'est extrêmement important.
# Donc en l'état, il y a plein de situations illégales que les cliniciens ont organisées dans leur coin mais qui n'est pas possible d'arrêter.
# Et la conséquence de ne pas pouvoir les faire rentrer dans les clous, c'est aussi que lorsqu'il y a des besoins de collaboration avec des structures extérieures, des groupes de recherche extérieures, moi, pour l'instant, je dis que ce n'est pas légal.
# Ces données ne sont pas légales.
# Elles ne sont pas recueillies de manière légale ni conservées de manière légale.
# Je ne crois pas qu'il est bien pour la PHP de faire des contrats autour de l'échange de ces données-là.
# Mais c'est totalement insatisfaisant.
# Et les...
# Les médecins qui s'occupent de ça sont absolument furieux qu'on ne soit pas capable de leur proposer des solutions qui mettent tout ça dans les clous et qui permettent une utilisation scientifiquement correcte des données.
# --------- Communication ----------
#
# Comment utiliser, avoir recours aux données de l'EDS ?
# Comment faire ?
# Pour l'instant, c'est flou pour l'immense majorité.
# Il y a des points qui ne restent quand même pas clairs, mais qui ne sont pas extrêmement importants.
# C'est les collégiales ont-elles un droit de veto sur la réalisation des études ?
# C'est rarement.
# Enfin, dans mon expérience, ça n'a jamais été un point.
# Mais il m'a semblé qu'il peut y avoir une ambiguïté là, parce que moi, j'étais absolument convaincu qu'il y avait un besoin de les informer uniquement.
# Et à un moment, quelqu'un m'a dit « Ah non, non, il faut qu'elles soient d'accord. »
# Ce n'est pas du tout pareil.
# Moi, dans ma tête aussi, c'était une lettre d'information à la collégiale.
# C'était ce charpente qui donnait son avis favorable.
# Et il me semble que cette idée, je me demande si ce n'est pas Sandrine Baudouin qui...
# Enfin, qui, dans un échange, me paraissait envisager qu'il y avait un besoin de validation de leur part.
# L'avertissement, c'est oh là là, ça va être compliqué.
# Il faut être prêt.
# Ça va être compliqué.
# On va découvrir que les...
# Les données ne sont pas là, on va découvrir que les données sont de mauvaise qualité, on va découvrir qu'il faut travailler plus qu'on ne le pensait.
# Mais il faut bien y aller, mais c'est le message que je donne, il faut bien y aller pour le découvrir et pour qu'ensuite les choses soient plus balisées.
# Mais c'est encore, c'est encore effectivement avec cette introduction prudente qu'on fait toutes les discussions en rapport avec l'utilisation de l'UDS.
# Les échanges avec l'EDSN sont lourds.
# Ils sont lourds ?
# Oui.
# Moi, j'ai l'impression d'avoir vu des réunions où je me dis, pourquoi vous êtes autant que ça ?
# D'accord.
# Ah, j'ai l'impression de perdre votre temps dans cette réunion.
# l'accompagnement de l'EDSN, que ce soit positive ou négative.
# Pour moi, là, pour moi, là, c'est encore insatisfaisant.
# Mon ressenti personnel, il est insatisfait de mes appréciations.
# Interaction avec la DSN.
# La difficulté, je crois, pour la DSN, c'est de créer, avec l'Ilo, un service d'accompagnement.
# Mais, donc, de mon point de vue, le niveau n'est pas encore bon.
# S'il était bon, vous ne seriez pas là à vous interroger.
# Donc, c'est bien parce que vous partagez ça que vous y travaillez.
# Et du coup, je suis d'accord avec cette idée qu'il faut y travailler encore.
# Je reviens sur un point, je pense qu'il y a quelque chose sur lequel il faut travailler, c'est la proximité avec la DRCI.
# Je n'ai pas toujours eu l'impression, et c'est vraiment important que ce soit le cas, je n'ai pas toujours eu l'impression d'avoir en face une équipe qui était dédiée au soutien de la recherche.
# Mais ça a été le cas aussi tout récemment avec Caldif.
# Caldif a été dans le périmètre, vous avez suivi, a été dans le périmètre.
# Il n'a pas été considéré hors du périmètre, jusqu'à ce qu'à un moment, mauvaise surprise pour moi, ça a été considéré comme hors du périmètre de la DSN.
# Si ça l'était, si ça l'a été pendant sept mois, comment est-ce que je peux, comment imaginer la difficulté pour expliquer aux porteurs de projets, cliniciens, ah ben la DSN vient maintenant me dire que c'est hors de son périmètre.
# La Fanny Bochel, la porteuse du projet, elle me dit, mais est-ce qu'il faut que j'aille voir le directeur général ?
# Donc furieux de cette mauvaise, de cette mauvaise nouvelle.
# Et ça, ça pour moi, ça illustre un point, d'abord, d'abord que rien ne doit être hors du périmètre de la structure dédiée à la recherche clinique.
# Il y a peut-être tort en pensant que c'est trop cher.
# Il y a peut-être tort.
# Mais ça demande de comprendre.
# Elle est légitime.
# Et pour l'instant, je pense que la DSN, ce n'est pas encore vu comme suffisamment au service de la recherche pour ressentir cette légitimité et apporter des réponses satisfaisantes aux interlocuteurs.
# Mais ça viendra avec la proximité.
# Les réunions qui s'appellent CSSI.
# CSSI, oui.
# Ok.
# Et trop nombreux.
# Et est-ce que vous avez quand même eu l'impression que l'échange était fructueux, mais pas forcément le temps d'avoir autant de monde ?
# Oui, oui.
# Alors, fructueux ou pas, mais en tout cas, des échanges nécessaires pour avancer ensemble.
# Mais effectivement, je suis sorti de la réunion en me demandant pourquoi un tel, un tel et un tel avaient été présents finalement.
# Alors, c'est compliqué.
# Je n'ai pas une vision claire de l'organisation de la DSM.
# --------- Fonctionnalités ----------
#
# Et l'autre point, c'est le fait qu'il faut qu'il y ait une capacité qui va croissante et on a de plus en plus besoin de puissance de calcul.
# On fait de plus en plus de simulations, soit visées de simulation ou d'essais ou dans des approches de type Bayesienne, MCMC.
# Donc ils ont besoin de plus de puissance de calcul.
# Et de temps en temps, moi, il m'est arrivé de faire une simulation qui prenait 4 jours, 5 jours.
# C'est un peu exceptionnel, la plupart des simulations sont beaucoup plus courtes que ça, mais si je fais une simulation et qu'elle me prend 5 jours, je ne peux pas jouer avec les paramètres de ma simulation.
# Je n'ai pas assez de puissance de calcul pour jouer avec les paramètres.
# Et donc, du coup, de temps en temps, j'ai souvent besoin d'une machine plus rapide que celle que j'ai, mais de temps en temps, j'aurais besoin d'un calculateur qui me donnerait un nombre de cœurs plus important, en l'occurrence CPU et pas encore GPU, mais ça va venir, un nombre de cœurs plus important que j'ai sur ma machine.
# --------- Type/dispo/structure des données ----------
#
# Enfin, je dis ils collectivement, enfin, c'est entre eux, l'équipe et la DSN, réussit à constituer une cohorte de patients diabétiques.
# Donc, ils étaient assez contents jusqu'à ce qu'ils découvrent qu'une autre...
# La même demande formulée par une autre équipe, je crois que c'est ça l'histoire, la même demande formulée par une autre équipe avait abouti à une cohorte avec 100 000 patients de plus qui auraient déjà dû être inclus dans la première cohorte.
# Et c'est une situation où les choses, si on regarde d'un peu loin, devraient être simples.
# Identifier un patient diabétique, c'est extrêmement simple.
# Il y a un seul marqueur, enfin, il y a deux marqueurs, l'HB1C ou la glycémie.
# Donc, il ne devrait pas y avoir de mauvaise surprise.
# Et malgré tout, il y en a.
# Donc, il n'y a pas, à mon sens, il n'y a pas d'autre objectif à poursuivre que celui de faire en sorte que tout le dossier médical soit dans l'ODS.
# EDS, ça dit, je mets des données dans des fichiers, je ne sais pas encore pourquoi et je ne sais pas pour combien de temps.
# C'est ça en EDS.
# Ça ne dit pas que ça doit être exclusif du dossier médical.
# Mais l'autorisation, elle peut être exclusive du dossier médical.
# C'est une question de supposé.
# Est-ce que la CNIL a autorisé d'enrichir l'ODS avec des données de recherche ?
# C'est un entrepôt.
# Donc ces données, à un moment, on voudrait les conserver pour des objectifs à long terme non encore définis.
# Donc les transformer en entrepôts, au sens légal, au sens réglementaire.
# Et une des options éventuelles, c'est de dire « cet entrepôt, on va l'organiser sous la forme d'un sous-entrepôt de l'ODS ».
# OK ?
# Et une fois que je me suis posé cette question, j'ai réalisé que je ne savais pas si l'autorisation CNIL allait permettre ça.
# Et aujourd'hui, il y a 5 000 services qui se disent, mais moi, ces données-là, je veux les garder.
# Alors, ceux qui viennent...
# Et quand je dis 5 000, j'exagère, bien sûr, mais plein, tous les services.
# Je vous avais évoqué.
# Tous les services.
# Et moi, j'ai ces données, je veux les garder.
# Et je leur dis, mais tu veux les garder pour faire une recherche ?
# Ah oui, je veux faire une recherche.
# Alors, je leur explique la différence recherche-entrepot.
# Et très souvent, ils veulent les garder au-delà de la recherche en question.
# À ce moment-là, on a plusieurs options.
# Alors, soit on triche et on appelle recherche un truc qui est un entrepôt.
# Mais c'est ennuyeux de tricher.
# Une autre possibilité, c'est de dire, débrouillez-vous de discuter avec la DSN qui vous met ça dans Orbis et qui s'arrange pour que ça intègre l'entrepot.
# Ça, c'est fait.
# C'est des adaptations d'Orbis à des besoins spécifiques.
# La DSN travaille à ça.
# De temps en temps, répond favorablement.
# J'ai l'impression que pas tout le temps.
# J'ai l'impression que c'est compliqué.
# Dans le cadre du soin.
# Par exemple, les données de rythmologie.
# Les données de rythmologie, donc on fait des électrocardiogrammes avec plein de données et seulement très peu intègrent Orbis et l'entrepôt.
# --------- Général ----------
#
# Quel est le niveau de compétence en data science des médecins et des chercheurs qui viennent vous voir à l'URC?
# Alors, nul pour la plupart.
# Nul pour la plupart, mais en croissance, puisque tout le monde veut en faire et pense en faire, y compris les médecins.
# Mais en tout cas, sur les aspects un peu innovants, machine learning, intelligence artificielle, voilà, le niveau est nul et en croissance.
# Si le directeur général dit, mais ces données, c'est du dossier médical, ça devient du dossier médical.
# Et là, moi, il me manque une visibilité sur cette histoire-là.
# Ça dépend de...
# Ça dépend de notre institution que de dire que ces données relèvent au dossier médical.
# Or, Orbis est un élément important du dossier médical.
# Pourtant, la loi, elle ne dit pas, le dossier médical s'appelle Orbis.
# On est d'accord ?
# Le dossier médical, c'est ce qui est collecté par les établissements pour assurer le suivi des patients.
# Le dossier médical, c'est ça.
# Et c'est organisé par les établissements, pas par les docteurs.
# Très important.
# Et il y a une jurisprudence là-dessus.
# Le dossier médical, c'est l'établissement.
# Mais il y a un besoin, je le dis comme ça parce que je crois qu'il y a un besoin d'analyse de ce sujet-là.
# Dire que c'est du dossier médical pour l'établissement,
# c'est aussi dire que je ferai droit à toute la réglementation qui concerne le dossier médical et ce qui concerne ces données aussi.
# --------- Méthodologie ----------
#
# Il y a une idée qu'il faut étudier quelque chose.
# Vous voyez, comme je le dis de manière floue et imprécise.
# Et au-delà de ça, certains ont une vision extrêmement précise de qu'est-ce qu'il faut étudier, sur la base de quels critères, sur la base de quels patients et avec quelle méthodologie.
# Et puis pour d'autres, c'est plus flou.
# Il faut étudier ça et tout le reste est à développer.
# Donc le travail qui est fait ici, c'est le plus souvent d'abord le travail de...
# De clarifier les objectifs de la recherche.
# Très souvent, une fois sur deux, deux fois sur trois, le clinicien, il a une intuition qui est toujours présente.
# L'intuition est toujours présente et toujours intéressante.
# Mais quoi étudier chez quel patient avec quels critères ?
# Très souvent, c'est flou.
# Donc le premier travail qui est fait ici, c'est d'identifier ça.
# Et ce travail de maturation, c'est quelquefois le travail le plus compliqué.
# Donc la distinction entre les deux, utiliser des données qui existent, ou non, elle est liée à la nécessité ou non de mettre le patient dans une situation particulière.
# --------- Contournement ----------
#
# --------- Pilotage ----------
#
# --------- Argent ----------
#
# Il y a des progrès de communication à faire.
# Et là encore, si vous êtes là, c'est probablement que vous avez...
# Vous l'avez ressenti.
# Il y a par exemple eu un gros couac du côté de la DSN, quand la DSN s'est mise à demander de l'argent.
# C'est parfaitement légitime.
# C'est parfaitement légitime que les ressources soient financées par des projets.
# Enfin, c'est parfaitement légitime.
# Sauf que ce qui n'est pas légitime, c'est d'en faire la surprise au monde.
# Ça, c'est pas du tout légitime.
# Et ça s'est fait sans aucune information.
# Et donc, à un moment, on a découvert que la DSN demandait des budgets.
# À nouveau, c'est très légitime, nous, on passe notre temps à le faire, mais ça a été une surprise totale.
# Et donc, ça a été une surprise qui est arrivée au milieu d'un projet qui était en cours, qui avait besoin d'aide informatique, et grande nouveauté, cette aide informatique s'est arrêtée à être facturée.
# Mais voilà, c'est le genre de choses qu'on ne peut pas faire.
# Ce n'est pas de demander des budgets, mais de faire ce genre de surprise, de changer les règles en cours, en cours de route.
# Il faut penser qu'on ne peut pas faire, on ne peut pas changer les règles en cours de route et en faire la surprise à ses partenaires internes à l'institution.
# — L'évaluation des budgets doit aussi être… s'améliorer.
# Et s'améliorer, c'est…
# Moi, les budgets que j'ai eus… J'ai tous trouvé excessifs.
# Bon, je peux me tromper.
# Mais en tout cas, après échange, j'ai continué de les trouver excessifs.
# Et à minima… Donc j'avais tort ou raison sur leur caractère excessif.
# Mais là où j'ai raison, forcément, c'est de ne pas avoir eu suffisamment d'informations qui m'aient permis de changer d'avis.
# Il ne faut pas que la DSN voit les projets comme des occasions de se financer en structure.
# Alors en même temps, si la DSN n'a pas d'autres choix… Enfin je comprends ces difficultés, mais…
# Donc en tout cas, il faut que la DSN dise à la direction générale que ben non, on ne peut pas requêter les projets pour nous financer en structure.
# Ça ne peut pas marcher du côté des projets.
# Donc ça, c'est très important.
# Parce que j'ai deux projets en tête quand même.
# Deux projets en tête quand même qui ne se sont pas faits pour des budgets excessifs.
# Et que je crois, et que je continue de penser excessifs.
# Et donc pour lesquels on rend l'argent.
# Et bien non, on ne peut pas.
# C'est StratCovid et Capdif.
# --------- NLP ----------
#
# --------- Réglementation ----------
#
# On touche une donnée du patient, il faut l'informer.
# Bon, c'est insupportable mais c'est ainsi.
# par exemple, est-ce que l'information qui est mentionnée sur les comptes rendus peut être utilisée pour la réutilisation des données des patients du dossier médical ?
# Oui, non.
# Alors, dans l'absolu, l'information, elle pourrait être de, pourquoi pas, sauf que derrière, il faudrait mettre toutes les recherches sur le portail de transparence.
# Ah, ben là, je n'ai plus accès au portail de transparence parce qu'il est réservé à l'EDS.
# Donc, je n'ai pas de portail de transparence.
# Ensuite, pareil pour les données de l'entrepôt de l'HEGP.
# Mais ils sont prévenus que leurs données sont dans un entrepôt.
# Oui, mais ce n'est pas celui de l'HEGP.
# Mais les patients, ils ne font pas la différence entre l'HEGP et l'entrepôt central.
# Oui, donc on ne va pas leur mettre un deuxième pavé avec vous êtes aussi dans l'autre entrepôt.
# Mais il faut quand même les prévenir des recherches qui sont faites.
# Ah, ben, on ne va pas mettre les recherches faites sur l'entrepôt de l'HEGP sur le portail de transparence de l'entrepôt du siège.
# Ah, du coup, en fait, finalement, la seule solution qui marche bien, c'est de réinformer tous les patients.
# Sur le fond, il faudrait systématiquement renvoyer les courriers.
# chaque autorisation, elle couvre un périmètre qui est différent et qui ne couvre jamais celui dont on a vraiment besoin sauf quand on est typiquement dans les rails et où, au final, la qualité de l'information du patient, elle est quand même pourrie avec personne qui est capable de répondre à ces questions sur la totalité des traitements de données qui sont faites.
# Donc, la qualité de l'information, elle est de bonne qualité
# si on a une inspection de la CNIL, de mauvaise qualité si on demande l'avis du patient.
# Un truc tout bête, c'est par exemple quand on fait des recherches rétrospectives, il y a des fois où il faut envoyer un courrier à domicile et c'est tout.
# Je veux dire, on est capable d'envoyer des lettres de convocation aux patients, je ne sais pas combien l'AP envoie de courriers aux patients par an.
# On n'a pas mis ça en routine pour les recherches non interventionnelles.
# On préfère trouver un moyen de déroger
# à cette information du patient, passer à la CNIL plutôt qu'avoir un système pour le coup un peu bourrin de ça va, j'envoie 500 enveloppes, ça se fait bien quoi.
# Non, ça ne le fait pas.
# Et donc là, il y a vraiment des choses qui sont automatisables et simplifiables et c'est fait dans d'autres sites.
# et finalement, chaque donnée, elle est utilisée plusieurs fois donc potentiellement autorisée plusieurs fois.
# C'est impossible à suivre.
# Sur les recherches interventionnelles, on met des arcs pour aller monitorer le travail pour vérifier qu'il est bien fait.
# Et quand ils vont vérifier, le travail n'est pas fait, ils sont là pour le faire corriger.
# Donc si on ne met pas les arcs, le travail n'est pas fait.
# C'est pareil, toutes ces recherches-là, il n'y a personne pour vérifier, donc le travail n'est pas fait.
# J'ai des, tout un tas
# de registres et de cohortes qu'il faudrait requalifier en entrepôt et la moindre des choses, ça serait de les sécuriser d'un point de vue au moins informatique.
# Et là, on a des bases de données qui sont gérées par des médecins, etc.
# Et on touche à des domaines où il faut des compétences informatiques dures qu'on n'a pas.
# Donc là, il y a un vrai souci de...
# Il y a une offre de services et c'est des données qui sont importantes parce que c'est des données qui, aujourd'hui, sont de bien meilleure qualité que ce qu'il y a dans l'entrepôt.
# Donc ça serait dommage de ne pas les perdre.
# Les données de la recherche, c'est des données qui sont collectées pour la recherche.
# Elles sont monitorées, vérifiées, elles sont structurées d'emblée, elles sont réfléchies pour être utilisables.
# Elles seraient probablement...
# Le travail pour arriver
# à en faire quelque chose, à transformer le...
# Le charbon en diamant est probablement bien moindre que ce qui est nécessaire sur les données de soins sur l'entrepôt.
# --------- Communication ----------
#
# Il y a des médecins qui ne savent pas qu'il y a un entrepôt.
# Il y a des médecins qui savent qu'il y a un entrepôt, qui savent qu'il faut soumettre au comité scientifique et éthique, par exemple.
# Donc ça, c'est très variable.
# Et après, c'est compliqué.
# Donc, dans ce que je veux dire, c'est qu'à partir de ces points ponctuels qui sont, à mon avis, inadaptés dans le sens où ce n'est pas les bons interlocuteurs pour les bons besoins.
# Moi, les équipes avec qui j'ai travaillé, c'est simplement l'équipe de la CSSI.
# Et j'ai...
# Je n'ai jamais eu satisfaction.
# Je ne peux pas dire ça parce qu'en fait, ça dépend des étapes.
# Il y a des éléments où, je veux dire, la partie consultation, la faisabilité, tout ça, ils font ça bien.
# C'est clair.
# Ils ont des contraintes qui sont les leurs.
# Donc, je n'ai pas de souci.
# Après, il n'y a pas...
# Moi, je regrette l'absence de construction de projets possibles.
# Je suis irritée par l'absence d'implication dans les projets parce qu'en fait, ça m'irrite.
# Mais c'est comme ça qu'ils sont positionnés.
# Et les projets que j'ai faits ont planté parce qu'on a été abandonnés au fil de l'eau parce que ça nécessitait un accompagnement.
# Eux, ils s'attendent à être sollicités quand on a besoin d'eux.
# Et nous, on est sur des domaines qu'on ne connaît pas.
# Donc, finalement, c'est l'inverse.
# Ça serait plutôt l'inverse.
# Et donc, en fait, ils nous abandonnent.
# Et le dernier, on leur a payé un an temps plein d'ingénieurs et on a échangé nos données avec un disque dur externe parce qu'on n'avait plus de réponse.
# je ne sais pas comment sont gérées les priorités.
# Donc, je pense que ce n'est pas une volonté de nous mettre en difficulté.
# C'est qu'ils gèrent comme ils peuvent en fonction des urgences.
# Et on sait qu'il y a des urgences qui viennent d'en haut, plus ou moins adaptées.
# Les quelques demandes que j'ai vues venir d'en haut étaient totalement absurdes.
# Enfin, absurdes.
# Non.
# L'idée n'était pas absurde.
# Mais déconnectée de la réalité et de ce qui était faisable.
# Et donc, c'est vrai que si on fait passer ça en priorité et on s'engouffre
# dans un chantier qui va être un enfer parce qu'il n'est pas faisable pour des raisons qui sont politiques parce que ça a été demandé par telle personne.
# Je l'ai vu plusieurs fois.
# Ça, c'est vraiment ingérable.
# Après, les travaux qu'on a faits avec l'équipe de Christelle sur EHR tout EDC et...
# Avant, c'était EHR Forcer.
# Là, pour le coup, on était partenaire dans un projet.
# Là, c'était intéressant.
# Mais c'était un projet où on était impliqués.
# C'était Gilles Châtelier et moi sur la fin.
# Donc, on a fait
# un projet.
# Là, on travaillait ensemble.
# C'était un projet de l'ADSN où l'ADSN était impliqué parce que c'était un de ses projets et donc là, ça marche.
# Et donc, finalement, il faudra que les autres projets, ça soit des projets de l'ADSN.
# Il faut qu'il y ait une appropriation du projet.
# C'est tes projets, tu les aimes.
# Je pense qu'il y avait des tutoriels, des choses un peu accessibles, facilement, simplement.
# Alors, j'ai découvert qu'il y en avait un dans quoi ?
# Format PHP, là, mais il n'est pas accessible.
# C'est la formation à cohortes 360, c'est ça ?
# Mais voilà, j'ai découvert qu'il y avait une formation qui existait, mais qui ne m'était pas accessible.
# J'ai découvert parce qu'on a présenté la plateforme de formation et qu'ils m'ont dit par exemple, il y a 360.
# Donc, je pense qu'il y a des outils de présentation.
# Il y a de la com à faire, c'est de la com, c'est de la com avec des tutoriels, des vidéos, des choses faciles à prendre en main pour tout ce qui est usage en autonomie.
# On s'est dit que le fichier Excel est quand même vachement verrouillé.
# Non, mais en fait, après, je ne m'en sers pas parce que je ne vais pas sur l'entrepôt.
# Je trouve que ce que fait le HDH de bien, c'est la documentation et les aspects pédagogiques.
# Je suis tombée sur les outils de recette de...
# Le kit de recevabilité et de faisabilité au CSE.
# Non.
# Je l'ai encadré.
# C'est dans mon bureau.
# Ah, celui qui vient de sortir.
# Oui, mais voilà.
# Et donc, ils sont vraiment très, très forts sur ces choses-là et plus que sur l'utilisation de leurs données elles-mêmes.
# --------- Fonctionnalités ----------
#
# Les appareillements avec les SNDS, on me dit que c'est obligatoirement en passant par l'entrepôt.
# Je ne comprends pas pourquoi on est obligé de passer par l'entrepôt.
# Le principe des tableaux de bord, ça serait idéal pour nous si on avait un accès facile soit pour orienter les médecins en disant qu'il y a un intérêt parce qu'il y a à première vue suffisamment de données dans ces thématiques ou pas.
# Ça peut avoir un intérêt sur des évaluations grossières de faisabilité d'études cliniques pour identifier.
# Donc, les tableaux de bord, ça peut être pratique.
# Ça peut être aussi des outils qui permettent de vérifier rapidement qu'on a les mêmes données ici et là-bas.
# On a le même ordre de grandeur de données ici et là-bas.
# Donc, voilà, ça c'est pour les tableaux de bord.
# Les extractions, pour les projets où il y a besoin d'appariements de traitement des données individuelles, c'est indispensable.
# Alors, sur un espace Jupiter ou pas, ça m'est égal.
# Donc là, on est sur un format pour data manager
# à data scientist informaticien.
# Là, c'est indispensable pour faire de la recherche.
# Et puis, effectivement, il y a un besoin entre les deux pour probablement tout un tas de recherches que les médecins peuvent faire en autonomie et que je n'ai pas du tout envie de gérer pour eux.
# Et donc là, on est vraiment sur...
# du user-friendly.
# Il y a des données des patients d'ici qui sont traitées par nos stats.
# Et j'avais besoin d'une extraction des séjours de ces patients.
# On avait dit qu'il faudrait...
# On le puisse les avoir pour qu'ils les traitent
# avec leurs logiciels.
# Maintenant, ça sera sur Jupiter.
# Je dis oui, mais ils travaillent tous sous SAS.
# Et donc, ils ont dit non, on n'a pas SAS.
# D'accord ?
# Donc, on ne fait pas le projet.
# Ah, ce n'est pas nous qui faisons le...
# Donc, il y a une espèce de prise en otage.
# Non, vous avez un projet, mais vous ne pouvez pas le faire.
# Vous êtes obligés de nous déléguer la prestation de changer tout ce qui était prévu.
# Donc, il y a une problématique aussi d'architecture et de logiciel, d'outillage qui n'est pas forcément...
# Il y a la présentation, le tableau de bord d'extraction, etc.
# Et puis, les outils fournis avec.
# Et les outils fournis avec, je pense qu'il faut...
# Il faut qu'il y ait un peu de...
# de souplesse et quand on est sur des sujets innovants, ils sont toujours plus en avance que les opérationnels qui appliquent.
# Et Bastien, il travaillait là-dessus.
# C'est que nous, il y avait...
# Il était en train de développer un système de liste d'inclusion qui permettait d'avoir un red cap où le médecin, il avait le nom et le prénom du patient.
# Et en fait, ce nom et le prénom du patient, il était stocké en local dans le service du médecin et pas dans la base red cap.
# ta liste de correspondance entre ton identifiant recherche et ton nom et le prénom du patient, elle restait à l'échelle du médecin et elle n'était pas dans la base centralisée.
# Et donc, ça permettait le confort de travailler sur des données nominatives pour le médecin et puis il connaît
# Madame Pachin.
# Et en même temps, le respect des contrôles qu'on connaît sur l'anonymisation des données.
# --------- Type/dispo/structure des données ----------
#
# ...
# Donc là, la légitimité d'habilitation dans le cadre du projet de recherche.
# Et après, Jupiter, c'est un environnement de travail qui a l'air d'être pas mal du tout.
# Moi, je ne l'ai pas utilisé directement.
# C'est toujours mes étudiants qui l'ont utilisé.
# Qui ont tous mis un petit peu de temps à s'approprier l'organisation des données.
# Mais il y a une documentation qui est plutôt pas mal.
# Je ne sais pas si elle est actualisée en temps réel réel.
# Alors comment ça s'est passé, on a fait la demande d'accès au CSE.
# Moi j'ai assez l'habitude maintenant.
# Et puis il y avait la base Omap Covid Corona Omap.
# Ca a été un petit problème d'ailleurs.
# Enfin c'était un petit problème au niveau parce qu'en fait Jean-Simon Reich il avait commencé à faire des scripts d'extraction des données, enfin de data management et puis d'analyse, pour ses autres études sur la structure I2B2, et donc il a dû transformer avec l'aide d'Ariel, en fait c'est vous je crois d'ailleurs qui avez presque tout fait, qui avait transformé les scripts d'extraction et de traitement des données.
# Et ensuite il a fallu revenir à I2B2, c'est ça.
# Qui paraissent extrêmement longues, mais moi je trouve que c'est de mieux en mieux, d'examen par le CSE, de rendu de la décision, ensuite de mise à disposition, de spécification du besoin réel, et puis de mise à disposition des données.
# Mais ça, ça s'est passé sans trop trop de difficulté.
# De même qu'il y a eu un ou deux rafraîchissements qui se sont bien passés.
# Puis après, il a réussi à travailler sans difficulté sur l'espace Jupiter.
# Et là, c'est en cours.
# Le travail est finalisé.
# Il est en révision dans un journal.
# En revue dans un journal.
# --------- Type/dispo/structure des données ----------
#
# Et le fait qu'il y ait dans Orbi, c'est dans l'entrepôt de données de santé, la mortalité, enfin, les décès, c'est vraiment quelque chose.
# C'est une plus-value importante pour les corps de patients dans des maladies rares.
# Tout ce qui vient du CEPI-DC, effectivement.
# Donc ça, c'est une grosse, grosse valeur ajoutée, même si pour les patients drépanocytaires, en l'occurrence, ce n'est pas là où l'appareillement, je pense, est le plus facile.
# Parce que je pense que vous avez une politique très stricte pour importer les données.
# Et comme eux, ils ont souvent des noms qui sont mal orthographiés, leur numéro de sécurité sociale n'est pas forcément renseigné, on n'a pas toujours l'information.
# Mais en tout cas, c'est vraiment très, très utile.
# À la fois pour...
# et aussi pour la recherche.
# C'est vraiment très très précieux ça.
# BAMARA en fait...
# pas forcément pour...
# C'est assez pauvre cliniquement.
# En tout cas, nous, les informations qu'on y pousse, avec la fiche maladie rare dans ORMIS, c'est très très pauvre en fait.
# Il y a peut-être des cas où il n'y a pas de codage SIMDIS pour certaines maladies.
# Oui, dans ce cas-là, je crois que c'est un champ obligatoire.
# Du coup, on utilise le TESORUS ORFANET.
# L'identification des patients, ça peut vraiment le rajouter.
# Donc, on utilise pour moi un hôpital de jour en tout cas.
# Mais effectivement, quand il n'y a pas de code SIMDIS, ça peut être intéressant.
# vous ne voulez pas de faux positifs déclarés décédés en patients qui seraient encore vivants.
# Donc, il y a cette limite près qui fait que l'appareillement est incomplet.
# Je crois que c'est en dehors de 50% seulement des patients qu'on arrive à appareiller, enfin des...
# Voilà, ça, c'est très utile.
# Et puis après, notre autre appareillement utile, c'est avec le SNDS.
# Et donc là, je sais qu'il y a aussi des travaux pour essayer de simplifier le processus qui sont en cours.
# Pour le moment, ça reste encore très, très difficile.
# Par exemple, il y a, pour la demande d'accès au SMDS, on peut demander un accès soit par la plateforme du HDH, soit par la plateforme de la CNAM.
# Donc, la CNAM, c'est la plateforme historique sur laquelle on peut avoir les données qui sont livrées.
# Et puis, le HDH, comme vous le savez, c'est la nouvelle plateforme où, en théorie, il y a plus d'outils.
# Donc, nous, on avait demandé l'accès par la plateforme du HDH en se disant qu'on pourrait mettre en place plus d'outils, ça serait plus flexible.
# Mais en fait, le HDH demande qu'on fasse preuve que la transmission des données peut pouvoir se faire dans le respect du référentiel de sécurité.
# Et ça, la PHP n'a pas encore ces preuves-là.
# Alors que pour la plateforme de la CNAM, on les a.
# Et du coup, ça a risqué de faire capoter le projet parce qu'on ne savait pas qu'il aurait été préférable de demander l'accès par la plateforme historique de la CNAM.
# Là, il y a déjà eu des mises à disposition pour la PHP et donc la satisfaction du référentiel de sécurité est déjà documentée.
# Heureusement, on a pu demander à l'agent de la CNIL qui change juste cette ligne-là.
# Et du coup, j'en avais parlé à Serge Bureau parce que c'était vraiment un cauchemar, cette demande.
# Et Serge Bureau m'avait dit qu'ils étaient en train, justement, d'essayer d'établir une procédure d'accès aux données du SMDS et notamment quand c'est par le couplage avec le DS.
# Et je n'ai pas eu de nouvelles.
# Donc celui d'Yannis Lombardi, son projet de thèse, là, qui nécessite l'appareillement avec une base à redcap, et l'appareillement ensuite, donc APHP, une base APHP, qui n'est pas dans l'ODS, et l'appareillement avec le SNDS ensuite.
# Là, ça a été un petit peu plus compliqué.
# Il y a eu des raisons que j'ai déjà évoquées.
# Ça a été très vite au début, en fait.
# On a l'expérience maintenant.
# Donc la rédaction de la demande, puis l'accord du CSE a été très rapide.
# Mais c'est après pour réussir à comprendre les démarches suivantes et à les mettre en œuvre que ça a été un petit peu plus compliqué.
# Donc nous, on avait déposé le dossier, je pense, au CSE en novembre.
# Et finalement, l'autorisation d'accès, on a dû l'avoir en septembre de l'année suivante.
# Pas l'autorisation d'accès, mais l'autorisation d'accès aux données du SNDS.
# On a eu très, très vite l'accord du CSE pour l'accès aux données de l'EDS.
# Mais c'est après, pour l'accès au SNDS, que ça a pris six mois, en fait, presque neuf.
# par constater c'est que les dates de début étaient correctes et donc on pouvait s'appuyer sur la date de début pour reconstituer la trajectoire hospitalière du patient au cours d'un séjour.
# les requêtes, enfin les créations de cohortes en texte libre.
# J'ai l'impression qu'il y a des problèmes avec le...
# Le module de l'expression régulière sur les cohortes de l'I2B2 ?
# Sur les cohortes 360, oui.
# Et je peux vous donner des exemples.
# Quand on fait mot 1 ou mot 2, on n'a pas le même résultat que quand on fait mot 1, connecteur dans la...
# Oui, je vois.
# Et on peut les voir.
# Oui, il faut que je le fasse.
# Mais après, je parle plus des aspects réglementaires, de la mise à disposition des informations, ce qu'il y a dans l'EDS, ce qu'il n'y a pas dans l'EDS.
# Je pense que parfois, ça peut être difficile à comprendre.
# C'est ça, les attentes ne sont pas forcément alignées avec la réalité.
# Ils imaginent pouvoir retrouver tout ce qu'il y a dans Orbis, en fait.
# Très facilement.
# Oui, c'est-à-dire que ce n'est pas forcément le fonctionnement de l'outil en lui-même qui est utile.
# C'est que ça n'est qu'un contenant qui restitue la donnée telle qu'elle est et telle qu'elle a été intégrée.
# Donc, c'est plutôt là peut-être qu'il peut y avoir des expectations.
# --------- Général ----------
#
# et on l'utilise aussi en pédagogie.
# Donc nous on a avec nos étudiants des séances d'arc apprentissage du raisonnement clinique où on demande à un étudiant de jouer le rôle d'un patient et du médecin qui s'en occupe à la fois et les autres étudiants posent des questions en fait comme s'ils s'occupaient du patient et donc on identifie les cas qui vont servir de base à cette séance de simulation un petit peu en demandant à l'étudiant à partir de quelle situation il voudrait travailler par exemple, je ne sais pas, des douleurs articulaires ou une perte de poids importante ou une fièvre prolongée et on retrouve grâce à Core360 parmi les patients qu'on a pris en charge un ou quelques patients qui répondent à cette situation de départ et c'est à partir des cas réels finalement qu'ils construisent leur situation pédagogique.
# quand on les construit à partir d'un cas réel en fait ou d'un certain nombre d'informations qui sont des distracteurs en fait et qu'il faut savoir gérer donc on pourrait être un bon médecin donc voilà, utilisation pédagogique également et puis de temps en temps
# pour l'aide à la décision c'est arrivé à quelques reprises on a eu des patients un petit peu qui nous posaient des difficultés finalement dans la prise de décision thérapeutique notamment et on se rappelait qu'on avait déjà eu des patients qui ressemblaient et pour lesquels on avait déjà eu une discussion similaire mais on n'arrivait plus à la trouver et donc CORE 360 nous a permis de retrouver un patient similaire
# Après, il y a un autre domaine dans lequel on en attend beaucoup, nous, en médecine interne polyvalente, je dirais, où on s'occupe des maladies rares, mais on fait aussi l'aval des urgences.
# Donc, la maladie générale hospitalière, finalement.
# Oui.
# Sur laquelle il y a très, très peu de recherche en France.
# On est très en retard.
# Et on espère que l'entrepôt de données de santé va pouvoir nous aider à outiller de la recherche sur ces situations fréquentes prises en charge à l'hôpital.
# Ça, c'est un petit peu là-dessus.
# Christelle Gérardin, je pense que vous la connaissez.
# Donc, on aimerait qu'elle...
# Elle est interniste également.
# On aimerait qu'elle porte cette thématique clinique.
# Et en fait, les internistes, ils font leur recherche sur la maladie rare, en fait.
# Donc, ils n'ont pas du tout investi ce champ.
# Et on a beaucoup de retard par rapport à d'autres pays où la médecine interne n'a pas le même périmètre, en fait, où les internistes sont vraiment...
# Les médecins dévoluent à l'aval des urgences et ils ne font pas les maladies rares.
# C'est les rhumatologues aux Etats-Unis, par exemple.
# Les hospitalistes, ils font la médecine polyvalente et c'est les rhumatologues qui s'occupent des maladies rares, pas les médecins internistes.
# Donc, pour ces raisons-là, je pense que la recherche sur la situation fréquente hospitalière est très en retard en France.
# C'est important qu'on récupère le retard.
# Je pense que l'entrepôt de données de santé peut être utilisé.
# --------- Méthodologie ----------
#
# On parle des URQ.
# On a des dossiers qui arrivent en expertise au CSE et qui sont...
# Qui ont été préévalués par les data scientists sur les questions de faisabilité technique.
# Mais qui, en fait, ne sont pas analysables parce qu'ils ne sont pas bien spécifiés au plan scientifique, quoi.
# Donc, là, il y aurait probablement quelques choses à faire, je pense, pour accompagner les cliniciens à faire des projets de recherche qui soient mieux structurés.
# Et dont la faisabilité soit mieux évaluée, pas seulement sur le plan technique de possibilité de récupérer les données, mais aussi de s'assurer que les données qu'on récupère permettront de répondre à la question avec un niveau de validité suffisant pour que ça vaille la peine d'y investir du temps.
# Vous savez, je pense que les data scientists sont supposés faire cet accompagnement dans une certaine mesure.
# Mais je ne pense pas qu'ils aient les compétences et plus des techniciens, finalement.
# D'accord.
# Ils connaissent bien tous les tuyaux, tous les flux et ils sont capables de faire des estimations de population.
# Par contre, les éléments de conduite des projets de recherche, enfin, les schémas expérimentaux, les fondations, etc.
# Parfois, les porteurs de projets, ils ont des compétences méthodologiques ou ils s'associent avec des gens qui ont des compétences méthodologiques.
# Et donc là, il y a moins de problèmes, peut-être, et encore, ça se discute, parce que l'idéal, en fait, c'est à la fois de connaître les données et à la fois de savoir comment on les utilise.
# Et il ne suffit pas d'avoir quelqu'un qui connaît les données et quelqu'un qui sait comment on les utilise pour que l'analyse de la pertinence et de la...
# D'accord.
# des risques de biais soient complètes.
# Donc, il y aura besoin de développer un peu cet aspect à l'avant.
# C'est-à-dire la traduction de la question de recherche et de ce qu'elle englobe pour adresser de manière suffisamment exhaustive.
# Et puis, d'autre part, être capable de préjuger ou de prédire dans quelle mesure les données qui sont disponibles dans l'entrepôt permettent de répondre ensuite de façon valide.
# Ok.
# Valide et généralisable à la question.
# Ah oui, c'est-à-dire que la faisabilité ne soit pas juste la réponse à la question où les données existent.
# Sont disponibles.
# Oui.
# Mais que ce soit aussi la réponse à la question.
# Ça va répondre scientifiquement.
# Ça va répondre de façon fiable à la question de recherche.
# Donc, le CSE, il est censé faire ça.
# Dans des états très variables.
# Il est censé avoir une vision sur le...
# La pertinence scientifique du projet.
# Idéalement, il était aussi censé vérifier l'intérêt public de la question.
# Mais les compétences sont tellement hétérogènes, en fait, que ça dépend un petit peu du binôme sur lequel tombe le projet, en fait.
# --------- Contournement ----------
#
# --------- Pilotage ----------
#
# En tant que responsable de structure, j'utilise aussi pour du pilotage, je dirais, vraiment au niveau du terrain, pour comprendre les parcours de soins de mes patients, les flux.
# Pour nos patients drépanocytaires, par exemple, pour nos corps de patients qui ont des maladies rares, il y avait des problématiques concernant certains patients qui revenaient de façon très, très, très, très récurrente aux urgences, et qui perturbaient complètement les statistiques, mais aussi l'organisation des soins.
# Et donc on a pu, grâce à l'entrepreneuriat, suivre finalement le comportement, le recours aux soins de ces patients dans notre service.
# Pareil, quand on a des sollicitations de la direction pour rendre compte de nos IPDMS, de nos activités, c'est intéressant également d'avoir soi-même la possibilité d'accéder à un certain nombre de données, peut-être avec une granularité plus fine que les tableaux de bord qu'on nous envoie, et qui ne permettent pas forcément de rendre compte de notre situation ou d'expliquer, finalement, certaines anomalies identifiées dans nos statistiques.
# On a fait des travaux d'évaluation des pratiques également.
# Ça, je pense que c'est vraiment une utilisation intéressante, mais un petit peu dans la même idée que le pilotage, en fait.
# C'est d'améliorer, là, non pas les parcours, mais d'améliorer la prise en charge des patients, finalement.
# Donc on avait fait notamment des travaux sur le caractère approprié ou non de nos prescriptions de certains examens, comme les examens cytobactériologiques des urines, donc la recherche d'infections urinaires.
# On sait qu'il y a une surprescription, une malprescription.
# Et donc, voilà, on a fait des analyses sur l'ensemble des ECB.
# On a vu qu'on avait prescrit, et vraiment, c'était simplifiant d'avoir accès à d'autres données pour analyser le caractère approprié ou non des prescriptions, et puis avancer.
# De même qu'on peut faire des travaux un petit peu type RMM, c'est-à-dire identifier tous les patients qui sont décédés durant, je ne sais pas, les trois derniers mois, et avoir une réflexion d'équipe sur le caractère approprié ou non de leur prise en charge, leur caractère attendu, etc.
# Le caractère attendu ou non de leur décès, pareil pour les patients drépanocytaires.
# Ça, c'est quelque chose d'intéressant.
# Vous utilisez Pilote ?
# Non.
# Je ne pense pas y avoir accès, d'ailleurs.
# Je pensais ne pas y avoir accès, en fait, puisque c'est pour les DIMM et plus pour les… C'est vrai que les DIMM se positionnent beaucoup autour de Pilote.
# Et donc, moi, je pense que c'est pour les DIMM.
# --------- Argent ----------

# %%
mkdir /Users/perceval/Downloads/PDFs_annotés/PDF_extraction/

# %%
colors_by_label
# Out:
# {'label-0': 'rgb(255,161,55)',
#  'label-1': 'rgb(0,255,255)',
#  'label-2': 'rgb(255,183,230)',
#  'label-3': 'rgb(228,183,255)',
#  'label-4': 'rgb(255,255,0)',
#  'label-5': 'rgb(0,255,0)',
#  'label-6': 'rgb(91,103,255)',
#  'label-7': 'rgb(126,0,212)',
#  'label-8': 'rgb(0,132,164)',
#  'label-9': 'rgb(205,255,78)'}
