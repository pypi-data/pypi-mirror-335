# %% [markdown]
# Convert pretrained Tensorflow models (.h5) to pytorch

# %%
import h5py
import numpy as np
import requests
import torch
from torch import Tensor

# %%
def download_file(url, to):
    response = requests.get(url, stream=True)

    if response.status_code == 200:
        # Open a local file in write-binary mode and write the response content to it
        with open(to, "wb") as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        print(f"File downloaded successfully: {to}")
    else:
        print(f"Failed to download file: {response.status_code}")

# %%
xception_url = (
    "https://github.com/fchollet/deep-learning-models/"
    "releases/download/v0.4/"
    "xception_weights_tf_dim_ordering_tf_kernels.h5"
)
xception_file = "../assets/xception_weights.h5"
download_file(xception_url, xception_file)
# Out:
# File downloaded successfully: ../assets/xception_weights.h5

# %%
def flatten_h5(h5: h5py.File | h5py.Group) -> dict[str, h5py.Dataset]:
    contents: dict[str, h5py.Dataset] = {}
    for k, v in h5.items():
        if isinstance(v, (h5py.File, h5py.Group)):
            sub_contents = flatten_h5(v)
            with_prefix = {k + "/" + sk: sv for sk, sv in sub_contents.items()}
            contents.update(with_prefix)
        elif isinstance(v, h5py.Dataset):
            contents[k] = v
        else:
            raise ValueError(f"Unknown value", v)
    return contents

# %%
xception_h5: h5py.File = h5py.File(xception_file, "r")
xception_items = flatten_h5(xception_h5)
for k, v in xception_items.items():
    print(k, v.shape, v.dtype)
    v = np.array(v)  # convert to numpy first is much faster
    torch.tensor(v)
# Out:
# batchnormalization_1/batchnormalization_1_beta:0 (32,) float32
# batchnormalization_1/batchnormalization_1_gamma:0 (32,) float32
# batchnormalization_1/batchnormalization_1_running_mean:0 (32,) float32
# batchnormalization_1/batchnormalization_1_running_std:0 (32,) float32
# batchnormalization_10/batchnormalization_10_beta:0 (728,) float32
# batchnormalization_10/batchnormalization_10_gamma:0 (728,) float32
# batchnormalization_10/batchnormalization_10_running_mean:0 (728,) float32
# batchnormalization_10/batchnormalization_10_running_std:0 (728,) float32
# batchnormalization_11/batchnormalization_11_beta:0 (728,) float32
# batchnormalization_11/batchnormalization_11_gamma:0 (728,) float32
# batchnormalization_11/batchnormalization_11_running_mean:0 (728,) float32
# batchnormalization_11/batchnormalization_11_running_std:0 (728,) float32
# batchnormalization_12/batchnormalization_12_beta:0 (728,) float32
# batchnormalization_12/batchnormalization_12_gamma:0 (728,) float32
# batchnormalization_12/batchnormalization_12_running_mean:0 (728,) float32
# batchnormalization_12/batchnormalization_12_running_std:0 (728,) float32
# batchnormalization_13/batchnormalization_13_beta:0 (728,) float32
# batchnormalization_13/batchnormalization_13_gamma:0 (728,) float32
# batchnormalization_13/batchnormalization_13_running_mean:0 (728,) float32
# batchnormalization_13/batchnormalization_13_running_std:0 (728,) float32
# batchnormalization_14/batchnormalization_14_beta:0 (728,) float32
# batchnormalization_14/batchnormalization_14_gamma:0 (728,) float32
# batchnormalization_14/batchnormalization_14_running_mean:0 (728,) float32
# batchnormalization_14/batchnormalization_14_running_std:0 (728,) float32
# batchnormalization_15/batchnormalization_15_beta:0 (728,) float32
# batchnormalization_15/batchnormalization_15_gamma:0 (728,) float32
# batchnormalization_15/batchnormalization_15_running_mean:0 (728,) float32
# batchnormalization_15/batchnormalization_15_running_std:0 (728,) float32
# batchnormalization_16/batchnormalization_16_beta:0 (728,) float32
# batchnormalization_16/batchnormalization_16_gamma:0 (728,) float32
# batchnormalization_16/batchnormalization_16_running_mean:0 (728,) float32
# batchnormalization_16/batchnormalization_16_running_std:0 (728,) float32
# batchnormalization_17/batchnormalization_17_beta:0 (728,) float32
# batchnormalization_17/batchnormalization_17_gamma:0 (728,) float32
# batchnormalization_17/batchnormalization_17_running_mean:0 (728,) float32
# batchnormalization_17/batchnormalization_17_running_std:0 (728,) float32
# batchnormalization_18/batchnormalization_18_beta:0 (728,) float32
# batchnormalization_18/batchnormalization_18_gamma:0 (728,) float32
# batchnormalization_18/batchnormalization_18_running_mean:0 (728,) float32
# batchnormalization_18/batchnormalization_18_running_std:0 (728,) float32
# batchnormalization_19/batchnormalization_19_beta:0 (728,) float32
# batchnormalization_19/batchnormalization_19_gamma:0 (728,) float32
# batchnormalization_19/batchnormalization_19_running_mean:0 (728,) float32
# batchnormalization_19/batchnormalization_19_running_std:0 (728,) float32
# batchnormalization_2/batchnormalization_2_beta:0 (64,) float32
# batchnormalization_2/batchnormalization_2_gamma:0 (64,) float32
# batchnormalization_2/batchnormalization_2_running_mean:0 (64,) float32
# batchnormalization_2/batchnormalization_2_running_std:0 (64,) float32
# batchnormalization_20/batchnormalization_20_beta:0 (728,) float32
# batchnormalization_20/batchnormalization_20_gamma:0 (728,) float32
# batchnormalization_20/batchnormalization_20_running_mean:0 (728,) float32
# batchnormalization_20/batchnormalization_20_running_std:0 (728,) float32
# batchnormalization_21/batchnormalization_21_beta:0 (728,) float32
# batchnormalization_21/batchnormalization_21_gamma:0 (728,) float32
# batchnormalization_21/batchnormalization_21_running_mean:0 (728,) float32
# batchnormalization_21/batchnormalization_21_running_std:0 (728,) float32
# batchnormalization_22/batchnormalization_22_beta:0 (728,) float32
# batchnormalization_22/batchnormalization_22_gamma:0 (728,) float32
# batchnormalization_22/batchnormalization_22_running_mean:0 (728,) float32
# batchnormalization_22/batchnormalization_22_running_std:0 (728,) float32
# batchnormalization_23/batchnormalization_23_beta:0 (728,) float32
# batchnormalization_23/batchnormalization_23_gamma:0 (728,) float32
# batchnormalization_23/batchnormalization_23_running_mean:0 (728,) float32
# batchnormalization_23/batchnormalization_23_running_std:0 (728,) float32
# batchnormalization_24/batchnormalization_24_beta:0 (728,) float32
# batchnormalization_24/batchnormalization_24_gamma:0 (728,) float32
# batchnormalization_24/batchnormalization_24_running_mean:0 (728,) float32
# batchnormalization_24/batchnormalization_24_running_std:0 (728,) float32
# batchnormalization_25/batchnormalization_25_beta:0 (728,) float32
# batchnormalization_25/batchnormalization_25_gamma:0 (728,) float32
# batchnormalization_25/batchnormalization_25_running_mean:0 (728,) float32
# batchnormalization_25/batchnormalization_25_running_std:0 (728,) float32
# batchnormalization_26/batchnormalization_26_beta:0 (728,) float32
# batchnormalization_26/batchnormalization_26_gamma:0 (728,) float32
# batchnormalization_26/batchnormalization_26_running_mean:0 (728,) float32
# batchnormalization_26/batchnormalization_26_running_std:0 (728,) float32
# batchnormalization_27/batchnormalization_27_beta:0 (728,) float32
# batchnormalization_27/batchnormalization_27_gamma:0 (728,) float32
# batchnormalization_27/batchnormalization_27_running_mean:0 (728,) float32
# batchnormalization_27/batchnormalization_27_running_std:0 (728,) float32
# batchnormalization_28/batchnormalization_28_beta:0 (728,) float32
# batchnormalization_28/batchnormalization_28_gamma:0 (728,) float32
# batchnormalization_28/batchnormalization_28_running_mean:0 (728,) float32
# batchnormalization_28/batchnormalization_28_running_std:0 (728,) float32
# batchnormalization_29/batchnormalization_29_beta:0 (728,) float32
# batchnormalization_29/batchnormalization_29_gamma:0 (728,) float32
# batchnormalization_29/batchnormalization_29_running_mean:0 (728,) float32
# batchnormalization_29/batchnormalization_29_running_std:0 (728,) float32
# batchnormalization_3/batchnormalization_3_beta:0 (128,) float32
# batchnormalization_3/batchnormalization_3_gamma:0 (128,) float32
# batchnormalization_3/batchnormalization_3_running_mean:0 (128,) float32
# batchnormalization_3/batchnormalization_3_running_std:0 (128,) float32
# batchnormalization_30/batchnormalization_30_beta:0 (728,) float32
# batchnormalization_30/batchnormalization_30_gamma:0 (728,) float32
# batchnormalization_30/batchnormalization_30_running_mean:0 (728,) float32
# batchnormalization_30/batchnormalization_30_running_std:0 (728,) float32
# batchnormalization_31/batchnormalization_31_beta:0 (728,) float32
# batchnormalization_31/batchnormalization_31_gamma:0 (728,) float32
# batchnormalization_31/batchnormalization_31_running_mean:0 (728,) float32
# batchnormalization_31/batchnormalization_31_running_std:0 (728,) float32
# batchnormalization_32/batchnormalization_32_beta:0 (728,) float32
# batchnormalization_32/batchnormalization_32_gamma:0 (728,) float32
# batchnormalization_32/batchnormalization_32_running_mean:0 (728,) float32
# batchnormalization_32/batchnormalization_32_running_std:0 (728,) float32
# batchnormalization_33/batchnormalization_33_beta:0 (728,) float32
# batchnormalization_33/batchnormalization_33_gamma:0 (728,) float32
# batchnormalization_33/batchnormalization_33_running_mean:0 (728,) float32
# batchnormalization_33/batchnormalization_33_running_std:0 (728,) float32
# batchnormalization_34/batchnormalization_34_beta:0 (728,) float32
# batchnormalization_34/batchnormalization_34_gamma:0 (728,) float32
# batchnormalization_34/batchnormalization_34_running_mean:0 (728,) float32
# batchnormalization_34/batchnormalization_34_running_std:0 (728,) float32
# batchnormalization_35/batchnormalization_35_beta:0 (728,) float32
# batchnormalization_35/batchnormalization_35_gamma:0 (728,) float32
# batchnormalization_35/batchnormalization_35_running_mean:0 (728,) float32
# batchnormalization_35/batchnormalization_35_running_std:0 (728,) float32
# batchnormalization_36/batchnormalization_36_beta:0 (1024,) float32
# batchnormalization_36/batchnormalization_36_gamma:0 (1024,) float32
# batchnormalization_36/batchnormalization_36_running_mean:0 (1024,) float32
# batchnormalization_36/batchnormalization_36_running_std:0 (1024,) float32
# batchnormalization_37/batchnormalization_37_beta:0 (728,) float32
# batchnormalization_37/batchnormalization_37_gamma:0 (728,) float32
# batchnormalization_37/batchnormalization_37_running_mean:0 (728,) float32
# batchnormalization_37/batchnormalization_37_running_std:0 (728,) float32
# batchnormalization_38/batchnormalization_38_beta:0 (1024,) float32
# batchnormalization_38/batchnormalization_38_gamma:0 (1024,) float32
# batchnormalization_38/batchnormalization_38_running_mean:0 (1024,) float32
# batchnormalization_38/batchnormalization_38_running_std:0 (1024,) float32
# batchnormalization_39/batchnormalization_39_beta:0 (1536,) float32
# batchnormalization_39/batchnormalization_39_gamma:0 (1536,) float32
# batchnormalization_39/batchnormalization_39_running_mean:0 (1536,) float32
# batchnormalization_39/batchnormalization_39_running_std:0 (1536,) float32
# batchnormalization_4/batchnormalization_4_beta:0 (128,) float32
# batchnormalization_4/batchnormalization_4_gamma:0 (128,) float32
# batchnormalization_4/batchnormalization_4_running_mean:0 (128,) float32
# batchnormalization_4/batchnormalization_4_running_std:0 (128,) float32
# batchnormalization_40/batchnormalization_40_beta:0 (2048,) float32
# batchnormalization_40/batchnormalization_40_gamma:0 (2048,) float32
# batchnormalization_40/batchnormalization_40_running_mean:0 (2048,) float32
# batchnormalization_40/batchnormalization_40_running_std:0 (2048,) float32
# batchnormalization_5/batchnormalization_5_beta:0 (128,) float32
# batchnormalization_5/batchnormalization_5_gamma:0 (128,) float32
# batchnormalization_5/batchnormalization_5_running_mean:0 (128,) float32
# batchnormalization_5/batchnormalization_5_running_std:0 (128,) float32
# batchnormalization_6/batchnormalization_6_beta:0 (256,) float32
# batchnormalization_6/batchnormalization_6_gamma:0 (256,) float32
# batchnormalization_6/batchnormalization_6_running_mean:0 (256,) float32
# batchnormalization_6/batchnormalization_6_running_std:0 (256,) float32
# batchnormalization_7/batchnormalization_7_beta:0 (256,) float32
# batchnormalization_7/batchnormalization_7_gamma:0 (256,) float32
# batchnormalization_7/batchnormalization_7_running_mean:0 (256,) float32
# batchnormalization_7/batchnormalization_7_running_std:0 (256,) float32
# batchnormalization_8/batchnormalization_8_beta:0 (256,) float32
# batchnormalization_8/batchnormalization_8_gamma:0 (256,) float32
# batchnormalization_8/batchnormalization_8_running_mean:0 (256,) float32
# batchnormalization_8/batchnormalization_8_running_std:0 (256,) float32
# batchnormalization_9/batchnormalization_9_beta:0 (728,) float32
# batchnormalization_9/batchnormalization_9_gamma:0 (728,) float32
# batchnormalization_9/batchnormalization_9_running_mean:0 (728,) float32
# batchnormalization_9/batchnormalization_9_running_std:0 (728,) float32
# convolution2d_1/convolution2d_1_W:0 (3, 3, 3, 32) float32
# convolution2d_2/convolution2d_2_W:0 (3, 3, 32, 64) float32
# convolution2d_3/convolution2d_3_W:0 (1, 1, 64, 128) float32
# convolution2d_4/convolution2d_4_W:0 (1, 1, 128, 256) float32
# convolution2d_5/convolution2d_5_W:0 (1, 1, 256, 728) float32
# convolution2d_6/convolution2d_6_W:0 (1, 1, 728, 1024) float32
# dense_2/dense_2_W:0 (2048, 1000) float32
# dense_2/dense_2_b:0 (1000,) float32
# separableconvolution2d_1/separableconvolution2d_1_depthwise_kernel:0 (3, 3, 64, 1) float32
# separableconvolution2d_1/separableconvolution2d_1_pointwise_kernel:0 (1, 1, 64, 128) float32
# separableconvolution2d_10/separableconvolution2d_10_depthwise_kernel:0 (3, 3, 728, 1) float32
# separableconvolution2d_10/separableconvolution2d_10_pointwise_kernel:0 (1, 1, 728, 728) float32
# separableconvolution2d_11/separableconvolution2d_11_depthwise_kernel:0 (3, 3, 728, 1) float32
# separableconvolution2d_11/separableconvolution2d_11_pointwise_kernel:0 (1, 1, 728, 728) float32
# separableconvolution2d
pytorch_state_dict = pytorch_model.state_dict()
for k, v in pytorch_state_dict.items():
    print(k, v.shape, v.dtype)
# Out:
# entry_flow.0.weight torch.Size([32, 3, 3, 3]) torch.float32
# entry_flow.1.weight torch.Size([32]) torch.float32
# entry_flow.1.bias torch.Size([32]) torch.float32
# entry_flow.1.running_mean torch.Size([32]) torch.float32
# entry_flow.1.running_var torch.Size([32]) torch.float32
# entry_flow.1.num_batches_tracked torch.Size([]) torch.int64
# entry_flow.3.weight torch.Size([64, 32, 3, 3]) torch.float32
# entry_flow.4.weight torch.Size([64]) torch.float32
# entry_flow.4.bias torch.Size([64]) torch.float32
# entry_flow.4.running_mean torch.Size([64]) torch.float32
# entry_flow.4.running_var torch.Size([64]) torch.float32
# entry_flow.4.num_batches_tracked torch.Size([]) torch.int64
# entry_flow.6.residual_branch.0.weight torch.Size([128, 64, 1, 1]) torch.float32
# entry_flow.6.residual_branch.1.weight torch.Size([128]) torch.float32
# entry_flow.6.residual_branch.1.bias torch.Size([128]) torch.float32
# entry_flow.6.residual_branch.1.running_mean torch.Size([128]) torch.float32
# entry_flow.6.residual_branch.1.running_var torch.Size([128]) torch.float32
# entry_flow.6.residual_branch.1.num_batches_tracked torch.Size([]) torch.int64
# entry_flow.6.main_branch.1.0.weight torch.Size([64, 1, 3, 3]) torch.float32
# entry_flow.6.main_branch.1.1.weight torch.Size([128, 64, 1, 1]) torch.float32
# entry_flow.6.main_branch.2.weight torch.Size([128]) torch.float32
# entry_flow.6.main_branch.2.bias torch.Size([128]) torch.float32
# entry_flow.6.main_branch.2.running_mean torch.Size([128]) torch.float32
# entry_flow.6.main_branch.2.running_var torch.Size([128]) torch.float32
# entry_flow.6.main_branch.2.num_batches_tracked torch.Size([]) torch.int64
# entry_flow.6.main_branch.4.0.weight torch.Size([128, 1, 3, 3]) torch.float32
# entry_flow.6.main_branch.4.1.weight torch.Size([128, 128, 1, 1]) torch.float32
# entry_flow.6.main_branch.5.weight torch.Size([128]) torch.float32
# entry_flow.6.main_branch.5.bias torch.Size([128]) torch.float32
# entry_flow.6.main_branch.5.running_mean torch.Size([128]) torch.float32
# entry_flow.6.main_branch.5.running_var torch.Size([128]) torch.float32
# entry_flow.6.main_branch.5.num_batches_tracked torch.Size([]) torch.int64
# entry_flow.7.residual_branch.0.weight torch.Size([256, 128, 1, 1]) torch.float32
# entry_flow.7.residual_branch.1.weight torch.Size([256]) torch.float32
# entry_flow.7.residual_branch.1.bias torch.Size([256]) torch.float32
# entry_flow.7.residual_branch.1.running_mean torch.Size([256]) torch.float32
# entry_flow.7.residual_branch.1.running_var torch.Size([256]) torch.float32
# entry_flow.7.residual_branch.1.num_batches_tracked torch.Size([]) torch.int64
# entry_flow.7.main_branch.1.0.weight torch.Size([128, 1, 3, 3]) torch.float32
# entry_flow.7.main_branch.1.1.weight torch.Size([256, 128, 1, 1]) torch.float32
# entry_flow.7.main_branch.2.weight torch.Size([256]) torch.float32
# entry_flow.7.main_branch.2.bias torch.Size([256]) torch.float32
# entry_flow.7.main_branch.2.running_mean torch.Size([256]) torch.float32
# entry_flow.7.main_branch.2.running_var torch.Size([256]) torch.float32
# entry_flow.7.main_branch.2.num_batches_tracked torch.Size([]) torch.int64
# entry_flow.7.main_branch.4.0.weight torch.Size([256, 1, 3, 3]) torch.float32
# entry_flow.7.main_branch.4.1.weight torch.Size([256, 256, 1, 1]) torch.float32
# entry_flow.7.main_branch.5.weight torch.Size([256]) torch.float32
# entry_flow.7.main_branch.5.bias torch.Size([256]) torch.float32
# entry_flow.7.main_branch.5.running_mean torch.Size([256]) torch.float32
# entry_flow.7.main_branch.5.running_var torch.Size([256]) torch.float32
# entry_flow.7.main_branch.5.num_batches_tracked torch.Size([]) torch.int64
# entry_flow.8.residual_branch.0.weight torch.Size([728, 256, 1, 1]) torch.float32
# entry_flow.8.residual_branch.1.weight torch.Size([728]) torch.float32
# entry_flow.8.residual_branch.1.bias torch.Size([728]) torch.float32
# entry_flow.8.residual_branch.1.running_mean torch.Size([728]) torch.float32
# entry_flow.8.residual_branch.1.running_var torch.Size([728]) torch.float32
# entry_flow.8.residual_branch.1.num_batches_tracked torch.Size([]) torch.int64
# entry_flow.8.main_branch.1.0.weight torch.Size([256, 1, 3, 3]) torch.float32
# entry_flow.8.main_branch.1.1.weight torch.Size([728, 256, 1, 1]) torch.float32
# entry_flow.8.main_branch.2.weight torch.Size([728]) torch.float32
# entry_flow.8.main_branch.2.bias torch.Size([728]) torch.float32
# entry_flow.8.main_branch.2.running_mean torch.Size([728]) torch.float32
# entry_flow.8.main_branch.2.running_var torch.Size([728]) torch.float32
# entry_flow.8.main_branch.2.num_batches_tracked torch.Size([]) torch.int64
# entry_flow.8.main_branch.4.0.weight torch.Size([728, 1, 3, 3]) torch.float32
# entry_flow.8.main_branch.4.1.weight torch.Size([728, 728, 1, 1]) torch.float32
# entry_flow.8.main_branch.5.weight torch.Size([728]) torch.float32
# entry_flow.8.main_branch.5.bias torch.Size([728]) torch.float32
# entry_flow.8.main_branch.5.running_mean torch.Size([728]) torch.float32
# entry_flow.8.main_branch.5.running_var torch.Size([728]) torch.float32
# entry_flow.8.main_branch.5.num_batches_tracked torch.Size([]) torch.int64
# middle_flow.0.main_branch.1.0.weight torch.Size([728, 1, 3, 3]) torch.float32
# middle_flow.0.main_branch.1.1.weight torch.Size([728, 728, 1, 1]) torch.float32
# middle_flow.0.main_branch.2.weight torch.Size([728]) torch.float32
# middle_flow.0.main_branch.2.bias torch.Size([728]) torch.float32
# middle_flow.0.main_branch.2.running_mean torch.Size([728]) torch.float32
# middle_flow.0.main_branch.2.running_var torch.Size([728]) torch.float32
# middle_flow.0.main_branch.2.num_batches_tracked torch.Size([]) torch.int64
# middle_flow.0.main_branch.4.0.weight torch.Size([728, 1, 3, 3]) torch.float32
# middle_flow.0.main_branch.4.1.weight torch.Size([728, 728, 1, 1]) torch.float32
# middle_flow.0.main_branch.5.weight torch.Size([728]) torch.float32
# middle_flow.0.main_branch.5.bias torch.Size([728]) torch.float32
# middle_flow.0.main_branch.5.running_mean torch.Size([728]) torch.float32
# middle_flow.0.main_branch.5.running_var torch.Size([728]) torch.float32
# middle_flow.0.main_branch.5.num_batches_tracked torch.Size([]) torch.int64
# middle_flow.0.main_branch.7.0.weight torch.Size([728, 1, 3, 3]) torch.float32
# middle_flow.0.main_branch.7.1.weight torch.Size([728, 728, 1, 1]) torch.float32
# middle_flow.0.main_branch.8.weight torch.Size([728]) torch.float32
# middle_flow.0.main_branch.8.bias torch.Size([728]) torch.float32
# middle_flow.0.main_branch.8.running_mean torch.Size([728]) torch.float32
# middle_flow.0.main_branch.8.running_var torch.Size([728]) torch.float32
# middle_flow.0.main_branch.8.num_batches_tracked torch.Size([]) torch.int64
# middle_flow.1.main_branch.1.0.weight torch.Size([728, 1, 3, 3]) torch.float32
# middle_flow.1.main_branch.1.1.weight torch.Size([728, 728, 1, 1]) torch.float32
# middle_flow.1.main_branch.2.weight torch.Size([728]) torch.float32
# middle_flow.1.main_branch.2.bias torch.Size([728]) torch.float32
# middle_flow.1.main_branch.2.running_mean torch.Size([728]) torch.float32
# middle_flow.1.main_branch.2.running_var torch.Size([728]) torch.float32
# middle_flow.1.main_branch.2.num_batches_tracked torch.Size([]) torch.int64
# middle_flow.1.main_branch.4.0.weight torch.Size([728, 1, 3, 3]) torch.float32
# middle_flow.1.main_branch.4.1.weight torch.Size([728, 728, 1, 1]) torch.float32
# middle_flow.1.main_branch.5.weight torch.Size([728]) torch.float32
# middle_flow.1.main_branch.5.bias torch.Size([728]) torch.float32
# middle_flow.1.main_branch.5.running_mean torch.Size([728]) torch.float32
# middle_flow.1.main_branch.5.running_var torch.Size([728]) torch.float32
# middle_flow.1.main_branch.5.num_batches_tracked torch.Size([]) torch.int64
# middle_flow.1.main_branch.7.0.weight torch.Size([728, 1, 3, 3]) torch.float32
# middle_flow.1.main_branch.7.1.weight torch.Size([728, 728, 1, 1]) torch.float32
# middle_flow.1.main_branch.8.weight torch.Size([728]) torch.float32
# middle_flow.1.main_branch.8.bias torch.Size([728]) torch.float32
# middle_flow.1.main_branch.8.running_mean torch.Size([728]) torch.float32
# middle_flow.1.main_branch.8.running_var torch.Size([728]) torch.float32
# middle_flow.1.main_branch.8.num_batches_tracked torch.Size([]) torch.int64
# middle_flow
0.weight torch.Size([728, 1, 3, 3]) torch.float32
# exit_flow.0.main_branch.1.1.weight torch.Size([728, 728, 1, 1]) torch.float32
# exit_flow.0.main_branch.2.weight torch.Size([728]) torch.float32
# exit_flow.0.main_branch.2.bias torch.Size([728]) torch.float32
# exit_flow.0.main_branch.2.running_mean torch.Size([728]) torch.float32
# exit_flow.0.main_branch.2.running_var torch.Size([728]) torch.float32
# exit_flow.0.main_branch.2.num_batches_tracked torch.Size([]) torch.int64
# exit_flow.0.main_branch.4.0.weight torch.Size([728, 1, 3, 3]) torch.float32
# exit_flow.0.main_branch.4.1.weight torch.Size([1024, 728, 1, 1]) torch.float32
# exit_flow.0.main_branch.5.weight torch.Size([1024]) torch.float32
# exit_flow.0.main_branch.5.bias torch.Size([1024]) torch.float32
# exit_flow.0.main_branch.5.running_mean torch.Size([1024]) torch.float32
# exit_flow.0.main_branch.5.running_var torch.Size([1024]) torch.float32
# exit_flow.0.main_branch.5.num_batches_tracked torch.Size([]) torch.int64
# exit_flow.1.0.weight torch.Size([1024, 1, 3, 3]) torch.float32
# exit_flow.1.1.weight torch.Size([1536, 1024, 1, 1]) torch.float32
# exit_flow.2.weight torch.Size([1536]) torch.float32
# exit_flow.2.bias torch.Size([1536]) torch.float32
# exit_flow.2.running_mean torch.Size([1536]) torch.float32
# exit_flow.2.running_var torch.Size([1536]) torch.float32
# exit_flow.2.num_batches_tracked torch.Size([]) torch.int64
# exit_flow.4.0.weight torch.Size([1536, 1, 3, 3]) torch.float32
# exit_flow.4.1.weight torch.Size([2048, 1536, 1, 1]) torch.float32
# exit_flow.5.weight torch.Size([2048]) torch.float32
# exit_flow.5.bias torch.Size([2048]) torch.float32
# exit_flow.5.running_mean torch.Size([2048]) torch.float32
# exit_flow.5.running_var torch.Size([2048]) torch.float32
# exit_flow.5.num_batches_tracked torch.Size([]) torch.int64
# exit_flow.9.weight torch.Size([1000, 2048]) torch.float32
# exit_flow.9.bias torch.Size([1000]) torch.float32

# %%
print(len(xception_items))
print(len(pytorch_state_dict))
print("Difference = 40 because keras doesn't store batchnorm's num_batches_tracked")
# Out:
# 236
# 276
# Difference = 40 because keras doesn't store batchnorm's num_batches_tracked

# %%
from torch import nn

from src.pixseg.models.backbones.xception import SeparableConv


def h5_to_pth(items: dict[str, h5py.Dataset], model: nn.Module) -> dict[str, Tensor]:
    conv_keys: list[str] = []
    batch_norm_keys: list[str] = []
    separable_conv_keys: list[str] = []
    linear_keys: list[str] = []

    for name, module in model.named_modules():
        if isinstance(module, nn.Conv2d):
            conv_keys.append(name)
        if isinstance(module, nn.BatchNorm2d):
            batch_norm_keys.append(name)
        if isinstance(module, SeparableConv):
            separable_conv_keys.append(name)
        if isinstance(module, nn.Linear):
            linear_keys.append(name)
    conv_keys = [
        e for e in conv_keys if e.rsplit(".", maxsplit=1)[0] not in separable_conv_keys
    ]
    print(
        len(conv_keys), len(batch_norm_keys), len(separable_conv_keys), len(linear_keys)
    )

    assert (
        len(items)
        == len(conv_keys) * 1
        + len(batch_norm_keys) * 4
        + len(separable_conv_keys) * 2
        + len(linear_keys) * 2
    )

    state_dict: dict[str, Tensor] = {}
    for i, k in enumerate(conv_keys):
        data = items[f"convolution2d_{i+1}/convolution2d_{i+1}_W:0"]
        data = torch.tensor(np.array(data), dtype=torch.float32)
        data = data.permute(3, 2, 0, 1)
        state_dict[f"{k}.weight"] = data

    key_pairs = [
        ("gamma", "weight"),
        ("beta", "bias"),
        ("running_mean", "running_mean"),
        ("running_std", "running_var"),
    ]
    for i, k in enumerate(batch_norm_keys):
        for keras_name, torch_name in key_pairs:
            data = items[
                f"batchnormalization_{i+1}/batchnormalization_{i+1}_{keras_name}:0"
            ]
            data = torch.tensor(np.array(data), dtype=torch.float32)
            state_dict[f"{k}.{torch_name}"] = data

    separable_pairs = [
        ("depthwise_kernel", "0", (2, 3, 0, 1)),
        ("pointwise_kernel", "1", (3, 2, 0, 1)),
    ]
    for i, k in enumerate(separable_conv_keys):
        for keras_name, torch_name, resize in separable_pairs:
            data = items[
                f"separableconvolution2d_{i+1}/separableconvolution2d_{i+1}_{keras_name}:0"
            ]
            data = torch.tensor(np.array(data), dtype=torch.float32)
            data = data.permute(*resize)
            state_dict[f"{k}.{torch_name}.weight"] = data

    assert len(linear_keys) == 1
    linear_weight_data = items["dense_2/dense_2_W:0"]
    linear_weight_data = torch.tensor(np.array(linear_weight_data), dtype=torch.float32)
    linear_weight_data = linear_weight_data.permute(1, 0)
    state_dict["exit_flow.9.weight"] = linear_weight_data
    linear_bias_data = items["dense_2/dense_2_b:0"]
    linear_bias_data = torch.tensor(np.array(linear_bias_data), dtype=torch.float32)
    state_dict["exit_flow.9.bias"] = linear_bias_data

    return state_dict

# %%
state_dict = h5_to_pth(xception_items, pytorch_model)
for k, v in state_dict.items():
    assert pytorch_state_dict[k].shape == v.shape
assert len(state_dict) == len(xception_items)
torch.save(state_dict, "../assets/xception_imagenet.pth")
# Out:
# 6 40 34 1

# %%
# test
weights = Xception_Weights.IMAGENET1K
xception_original(weights=weights)
# Out:
# Xception(
#   (entry_flow): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): ResidualBlock(
#       (residual_branch): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (main_branch): Sequential(
#         (0): ReLU()
#         (1): SeparableConv(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#           (1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU()
#         (4): SeparableConv(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#           (1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       )
#     )
#     (7): ResidualBlock(
#       (residual_branch): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (main_branch): Sequential(
#         (0): ReLU()
#         (1): SeparableConv(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#           (1): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU()
#         (4): SeparableConv(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (5): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       )
#     )
#     (8): ResidualBlock(
#       (residual_branch): Sequential(
#         (0): Conv2d(256, 728, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (main_branch): Sequential(
#         (0): ReLU()
#         (1): SeparableConv(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (1): Conv2d(256, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU()
#         (4): SeparableConv(
#           (0): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (1): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (5): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       )
#     )
#   )
#   (middle_flow): Sequential(
#     (0): ResidualBlock(
#       (residual_branch): Identity()
#       (main_branch): Sequential(
#         (0): ReLU()
#         (1): SeparableConv(
#           (0): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (1): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU()
#         (4): SeparableConv(
#           (0): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (1): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (5): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ReLU()
#         (7): SeparableConv(
#           (0): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (1): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (8): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): ResidualBlock(
#       (residual_branch): Identity()
#       (main_branch): Sequential(
#         (0): ReLU()
#         (1): SeparableConv(
#           (0): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (1): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU()
#         (4): SeparableConv(
#           (0): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (1): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (5): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ReLU()
#         (7): SeparableConv(
#           (0): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (1): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (8): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): ResidualBlock(
#       (residual_branch): Identity()
#       (main_branch): Sequential(
#         (0): ReLU()
#         (1): SeparableConv(
#           (0): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (1): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU()
#         (4): SeparableConv(
#           (0): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (1): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (5): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ReLU()
#         (7): SeparableConv(
#           (0): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (1): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (8): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): ResidualBlock(
#       (residual_branch): Identity()
#       (main_branch): Sequential(
#         (0): ReLU()
#         (1): SeparableConv(
#           (0): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (1): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU()
#         (4): SeparableConv(
#           (0): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (1): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (5): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ReLU()
#         (7): SeparableConv(
#           (0): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (1): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (8): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): ResidualBlock(
#       (residual_branch): Identity()
#       (main_branch): Sequential(
#         (0): ReLU()
#         (1): SeparableConv(
#           (0): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (1): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU()
#         (4): SeparableConv(
#           (0): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (1): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (5): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ReLU()
#         (7): SeparableConv(
#           (0): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (1): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (8): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): ResidualBlock(
#       (residual_branch): Identity()
#       (main_branch): Sequential(
#         (0): ReLU()
#         (1): SeparableConv(
#           (0): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (1): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU()
#         (4): SeparableConv(
#           (0): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (1): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (5): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ReLU()
#         (7): SeparableConv(
#           (0): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (1): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (8): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): ResidualBlock(
#       (residual_branch): Identity()
#       (main_branch): Sequential(
#         (0): ReLU()
#         (1): SeparableConv(
#           (0): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (1): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU()
#         (4): SeparableConv(
#           (0): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (1): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (5): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ReLU()
#         (7): SeparableConv(
#           (0): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (1): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (8): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): ResidualBlock(
#       (residual_branch): Identity()
#       (main_branch): Sequential(
#         (0): ReLU()
#         (1): SeparableConv(
#           (0): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (1): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU()
#         (4): SeparableConv(
#           (0): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (1): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (5): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ReLU()
#         (7): SeparableConv(
#           (0): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (1): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (8): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (exit_flow): Sequential(
#     (0): ResidualBlock(
#       (residual_branch): Sequential(
#         (0): Conv2d(728, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (main_branch): Sequential(
#         (0): ReLU()
#         (1): SeparableConv(
#           (0): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (1): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU()
#         (4): SeparableConv(
#           (0): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (1): Conv2d(728, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (5): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       )
#     )
#     (1): SeparableConv(
#       (0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024, bias=False)
#       (1): Conv2d(1024, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (2): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU()
#     (4): SeparableConv(
#       (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#       (1): Conv2d(1536, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (5): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): AdaptiveAvgPool2d(output_size=1)
#     (8): Flatten(start_dim=1, end_dim=-1)
#     (9): Linear(in_features=2048, out_features=1000, bias=True)
#   )
# )
